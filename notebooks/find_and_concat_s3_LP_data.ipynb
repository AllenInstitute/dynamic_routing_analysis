# %%
import upath
from dynamic_routing_analysis import decoding_utils, path_utils

# %%
#find folders/files on S3 with decoding results

path=[]
del path
path=path_utils.DECODING_ROOT_PATH
# path=path_utils.DECODING_ROOT_PATH / 'test'

# path=path_utils.DECODING_ROOT_PATH / 'n_units_test_2024-11-06T00:18:30.855494'
# path=path_utils.DECODING_ROOT_PATH / 'n_units_test_medium_unit_criteria_2024-11-07T00:47:13.551561'
# path=path_utils.DECODING_ROOT_PATH / 'full_test_LDA_medcrit_2024-11-09T00:33:11.111162'
# path=path_utils.DECODING_ROOT_PATH / 'full_test_logreg_medcrit_2024-11-11T18:39:59.601162' / 're_run'
# path=path_utils.DECODING_ROOT_PATH / 'full_logreg_medcrit_2024-11-26T16:45:38.919765'###old###
# path=path_utils.DECODING_ROOT_PATH / 'full_logreg_medcrit_2024-11-26T23:54:35.702811'
# path=path_utils.DECODING_ROOT_PATH / 'full_logreg_medcrit_2024-11-26T23:54:35.702811' / 'summary_re_run_0'
# path=path_utils.DECODING_ROOT_PATH / 'full_logreg_medcrit_2024-11-26T23:54:35.702811' / 'summary_re_run_1'
# path=path_utils.DECODING_ROOT_PATH / 'logreg_many_nunits_0_2024-12-10-0'
# path=path_utils.DECODING_ROOT_PATH / 'test_ben_20241212'
# path=path_utils.DECODING_ROOT_PATH / 'test_all_sessions_2024-12-13_test'
# path=path_utils.DECODING_ROOT_PATH / 'test_ben_20241214'
# path=path_utils.DECODING_ROOT_PATH / 'logreg_many_n_units_medium_criteria_2024-12-18'
# path=path_utils.DECODING_ROOT_PATH / 'logreg_many_n_units_strict_criteria_2024-12-19'
path=path_utils.DECODING_ROOT_PATH / 'test'/ 'test_1_21_2025'

# filename='decoding_results_test_2024_10_28.pkl'
all_paths = []
all_filenames = []
csvs = []
# all_paths_0 = []
# all_filenames_0 = []
# csvs_0 = []
for file in path.glob('*'):
    # if file.is_file():
    all_paths.append(file)
    print(file)
    all_filenames.append(file.name)
    if 'results.csv' in str(file):
        csvs.append(file)

# for file in path_0.iterdir():
#     # if file.is_file():
#     all_paths_0.append(file)
#     print(file)
#     all_filenames_0.append(file.name)
#     if 'results.csv' in str(file):
#         csvs_0.append(file)
# Out:
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620263_2022-07-26_1_21_2025.json
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620263_2022-07-26_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620263_2022-07-26_decoder_confidence_all_trials.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620263_2022-07-26_decoder_confidence_all_trials.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620263_2022-07-26_decoder_confidence_all_trials_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620263_2022-07-26_decoder_confidence_all_trials_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620263_2022-07-26_decoder_confidence_before_after_target.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620263_2022-07-26_decoder_confidence_before_after_target.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620263_2022-07-26_decoder_confidence_before_after_target_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620263_2022-07-26_decoder_confidence_before_after_target_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620263_2022-07-26_decoder_confidence_by_switch.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620263_2022-07-26_decoder_confidence_by_switch.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620263_2022-07-26_decoder_confidence_by_switch_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620263_2022-07-26_decoder_confidence_by_switch_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620263_2022-07-26_decoder_confidence_dprime_by_block.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620263_2022-07-26_decoder_confidence_dprime_by_block.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620263_2022-07-26_decoder_confidence_dprime_by_block_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620263_2022-07-26_decoder_confidence_dprime_by_block_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620263_2022-07-26_decoder_confidence_versus_response_type.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620263_2022-07-26_decoder_confidence_versus_response_type.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620263_2022-07-26_decoder_confidence_versus_response_type_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620263_2022-07-26_decoder_confidence_versus_response_type_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620263_2022-07-26_decoder_confidence_versus_trials_since_rewarded_target.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620263_2022-07-26_decoder_confidence_versus_trials_since_rewarded_target.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620263_2022-07-26_decoder_confidence_versus_trials_since_rewarded_target_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620263_2022-07-26_decoder_confidence_versus_trials_since_rewarded_target_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620263_2022-07-26_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620263_2022-07-27_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620263_2022-07-27_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620264_2022-08-02_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620264_2022-08-02_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-15_1_21_2025.json
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-15_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-15_decoder_confidence_all_trials.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-15_decoder_confidence_all_trials.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-15_decoder_confidence_all_trials_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-15_decoder_confidence_all_trials_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-15_decoder_confidence_before_after_target.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-15_decoder_confidence_before_after_target.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-15_decoder_confidence_before_after_target_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-15_decoder_confidence_before_after_target_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-15_decoder_confidence_by_switch.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-15_decoder_confidence_by_switch.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-15_decoder_confidence_by_switch_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-15_decoder_confidence_by_switch_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-15_decoder_confidence_dprime_by_block.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-15_decoder_confidence_dprime_by_block.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-15_decoder_confidence_dprime_by_block_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-15_decoder_confidence_dprime_by_block_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-15_decoder_confidence_versus_response_type.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-15_decoder_confidence_versus_response_type.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-15_decoder_confidence_versus_response_type_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-15_decoder_confidence_versus_response_type_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-15_decoder_confidence_versus_trials_since_rewarded_target.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-15_decoder_confidence_versus_trials_since_rewarded_target.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-15_decoder_confidence_versus_trials_since_rewarded_target_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-15_decoder_confidence_versus_trials_since_rewarded_target_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-15_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-16_1_21_2025.json
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-16_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-16_decoder_confidence_all_trials.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-16_decoder_confidence_all_trials.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-16_decoder_confidence_all_trials_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-16_decoder_confidence_all_trials_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-16_decoder_confidence_before_after_target.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-16_decoder_confidence_before_after_target.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-16_decoder_confidence_before_after_target_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-16_decoder_confidence_before_after_target_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-16_decoder_confidence_by_switch.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-16_decoder_confidence_by_switch.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-16_decoder_confidence_by_switch_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-16_decoder_confidence_by_switch_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-16_decoder_confidence_dprime_by_block.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-16_decoder_confidence_dprime_by_block.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-16_decoder_confidence_dprime_by_block_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-16_decoder_confidence_dprime_by_block_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-16_decoder_confidence_versus_response_type.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-16_decoder_confidence_versus_response_type.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-16_decoder_confidence_versus_response_type_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-16_decoder_confidence_versus_response_type_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-16_decoder_confidence_versus_trials_since_rewarded_target.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-16_decoder_confidence_versus_trials_since_rewarded_target.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-16_decoder_confidence_versus_trials_since_rewarded_target_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-16_decoder_confidence_versus_trials_since_rewarded_target_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-16_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-17_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-17_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/628801_2022-09-19_1_21_2025.json
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/628801_2022-09-19_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/628801_2022-09-19_decoder_confidence_all_trials.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/628801_2022-09-19_decoder_confidence_all_trials.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/628801_2022-09-19_decoder_confidence_all_trials_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/628801_2022-09-19_decoder_confidence_all_trials_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/628801_2022-09-19_decoder_confidence_before_after_target.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/628801_2022-09-19_decoder_confidence_before_after_target.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/628801_2022-09-19_decoder_confidence_before_after_target_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/628801_2022-09-19_decoder_confidence_before_after_target_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/628801_2022-09-19_decoder_confidence_by_switch.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/628801_2022-09-19_decoder_confidence_by_switch.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/628801_2022-09-19_decoder_confidence_by_switch_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/628801_2022-09-19_decoder_confidence_by_switch_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/628801_2022-09-19_decoder_confidence_dprime_by_block.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/628801_2022-09-19_decoder_confidence_dprime_by_block.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/628801_2022-09-19_decoder_confidence_dprime_by_block_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/628801_2022-09-19_decoder_confidence_dprime_by_block_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/628801_2022-09-19_decoder_confidence_versus_response_type.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/628801_2022-09-19_decoder_confidence_versus_response_type.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/628801_2022-09-19_decoder_confidence_versus_response_type_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/628801_2022-09-19_decoder_confidence_versus_response_type_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/628801_2022-09-19_decoder_confidence_versus_trials_since_rewarded_target.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/628801_2022-09-19_decoder_confidence_versus_trials_since_rewarded_target.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/628801_2022-09-19_decoder_confidence_versus_trials_since_rewarded_target_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/628801_2022-09-19_decoder_confidence_versus_trials_since_rewarded_target_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/628801_2022-09-19_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636397_2022-09-26_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636397_2022-09-26_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636397_2022-09-27_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636397_2022-09-27_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636766_2023-01-23_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636766_2023-01-23_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636766_2023-01-24_1_21_2025.json
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636766_2023-01-24_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636766_2023-01-24_decoder_confidence_all_trials.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636766_2023-01-24_decoder_confidence_all_trials.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636766_2023-01-24_decoder_confidence_all_trials_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636766_2023-01-24_decoder_confidence_all_trials_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636766_2023-01-24_decoder_confidence_before_after_target.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636766_2023-01-24_decoder_confidence_before_after_target.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636766_2023-01-24_decoder_confidence_before_after_target_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636766_2023-01-24_decoder_confidence_before_after_target_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636766_2023-01-24_decoder_confidence_by_switch.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636766_2023-01-24_decoder_confidence_by_switch.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636766_2023-01-24_decoder_confidence_by_switch_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636766_2023-01-24_decoder_confidence_by_switch_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636766_2023-01-24_decoder_confidence_dprime_by_block.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636766_2023-01-24_decoder_confidence_dprime_by_block.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636766_2023-01-24_decoder_confidence_dprime_by_block_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636766_2023-01-24_decoder_confidence_dprime_by_block_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636766_2023-01-24_decoder_confidence_versus_response_type.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636766_2023-01-24_decoder_confidence_versus_response_type.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636766_2023-01-24_decoder_confidence_versus_response_type_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636766_2023-01-24_decoder_confidence_versus_response_type_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636766_2023-01-24_decoder_confidence_versus_trials_since_rewarded_target.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636766_2023-01-24_decoder_confidence_versus_trials_since_rewarded_target.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636766_2023-01-24_decoder_confidence_versus_trials_since_rewarded_target_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636766_2023-01-24_decoder_confidence_versus_trials_since_rewarded_target_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636766_2023-01-24_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644864_2023-02-02_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644864_2023-02-02_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-07_1_21_2025.json
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-07_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-07_decoder_confidence_all_trials.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-07_decoder_confidence_all_trials.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-07_decoder_confidence_all_trials_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-07_decoder_confidence_all_trials_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-07_decoder_confidence_before_after_target.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-07_decoder_confidence_before_after_target.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-07_decoder_confidence_before_after_target_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-07_decoder_confidence_before_after_target_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-07_decoder_confidence_by_switch.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-07_decoder_confidence_by_switch.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-07_decoder_confidence_by_switch_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-07_decoder_confidence_by_switch_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-07_decoder_confidence_dprime_by_block.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-07_decoder_confidence_dprime_by_block.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-07_decoder_confidence_dprime_by_block_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-07_decoder_confidence_dprime_by_block_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-07_decoder_confidence_versus_response_type.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-07_decoder_confidence_versus_response_type.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-07_decoder_confidence_versus_response_type_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-07_decoder_confidence_versus_response_type_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-07_decoder_confidence_versus_trials_since_rewarded_target.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-07_decoder_confidence_versus_trials_since_rewarded_target.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-07_decoder_confidence_versus_trials_since_rewarded_target_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-07_decoder_confidence_versus_trials_since_rewarded_target_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-07_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-08_1_21_2025.json
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-08_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-08_decoder_confidence_all_trials.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-08_decoder_confidence_all_trials.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-08_decoder_confidence_all_trials_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-08_decoder_confidence_all_trials_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-08_decoder_confidence_before_after_target.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-08_decoder_confidence_before_after_target.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-08_decoder_confidence_before_after_target_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-08_decoder_confidence_before_after_target_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-08_decoder_confidence_by_switch.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-08_decoder_confidence_by_switch.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-08_decoder_confidence_by_switch_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-08_decoder_confidence_by_switch_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-08_decoder_confidence_dprime_by_block.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-08_decoder_confidence_dprime_by_block.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-08_decoder_confidence_dprime_by_block_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-08_decoder_confidence_dprime_by_block_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-08_decoder_confidence_versus_response_type.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-08_decoder_confidence_versus_response_type.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-08_decoder_confidence_versus_response_type_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-08_decoder_confidence_versus_response_type_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-08_decoder_confidence_versus_trials_since_rewarded_target.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-08_decoder_confidence_versus_trials_since_rewarded_target.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-08_decoder_confidence_versus_trials_since_rewarded_target_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-08_decoder_confidence_versus_trials_since_rewarded_target_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-08_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-09_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-09_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-10_1_21_2025.json
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-10_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-10_decoder_confidence_all_trials.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-10_decoder_confidence_all_trials.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-10_decoder_confidence_all_trials_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-10_decoder_confidence_all_trials_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-10_decoder_confidence_before_after_target.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-10_decoder_confidence_before_after_target.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-10_decoder_confidence_before_after_target_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-10_decoder_confidence_before_after_target_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-10_decoder_confidence_by_switch.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-10_decoder_confidence_by_switch.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-10_decoder_confidence_by_switch_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-10_decoder_confidence_by_switch_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-10_decoder_confidence_dprime_by_block.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-10_decoder_confidence_dprime_by_block.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-10_decoder_confidence_dprime_by_block_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-10_decoder_confidence_dprime_by_block_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-10_decoder_confidence_versus_response_type.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-10_decoder_confidence_versus_response_type.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-10_decoder_confidence_versus_response_type_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-10_decoder_confidence_versus_response_type_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-10_decoder_confidence_versus_trials_since_rewarded_target.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-10_decoder_confidence_versus_trials_since_rewarded_target.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-10_decoder_confidence_versus_trials_since_rewarded_target_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-10_decoder_confidence_versus_trials_since_rewarded_target_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-10_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644867_2023-02-20_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644867_2023-02-20_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644867_2023-02-22_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644867_2023-02-22_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644867_2023-02-23_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644867_2023-02-23_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/646318_2023-01-17_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/646318_2023-01-17_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649943_2023-02-13_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649943_2023-02-13_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649943_2023-02-14_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649943_2023-02-14_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649943_2023-02-15_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649943_2023-02-15_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649943_2023-02-16_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649943_2023-02-16_decoder_confidence_all_trials_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649943_2023-02-16_decoder_confidence_all_trials_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649943_2023-02-16_decoder_confidence_before_after_target_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649943_2023-02-16_decoder_confidence_before_after_target_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649943_2023-02-16_decoder_confidence_by_switch_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649943_2023-02-16_decoder_confidence_by_switch_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649943_2023-02-16_decoder_confidence_dprime_by_block_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649943_2023-02-16_decoder_confidence_dprime_by_block_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649943_2023-02-16_decoder_confidence_versus_response_type_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649943_2023-02-16_decoder_confidence_versus_response_type_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649943_2023-02-16_decoder_confidence_versus_trials_since_rewarded_target_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649943_2023-02-16_decoder_confidence_versus_trials_since_rewarded_target_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649943_2023-02-16_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649944_2023-02-27_1_21_2025.json
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649944_2023-02-27_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649944_2023-02-27_decoder_confidence_all_trials.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649944_2023-02-27_decoder_confidence_all_trials.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649944_2023-02-27_decoder_confidence_all_trials_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649944_2023-02-27_decoder_confidence_all_trials_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649944_2023-02-27_decoder_confidence_before_after_target.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649944_2023-02-27_decoder_confidence_before_after_target.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649944_2023-02-27_decoder_confidence_before_after_target_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649944_2023-02-27_decoder_confidence_before_after_target_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649944_2023-02-27_decoder_confidence_by_switch.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649944_2023-02-27_decoder_confidence_by_switch.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649944_2023-02-27_decoder_confidence_by_switch_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649944_2023-02-27_decoder_confidence_by_switch_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649944_2023-02-27_decoder_confidence_dprime_by_block.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649944_2023-02-27_decoder_confidence_dprime_by_block.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649944_2023-02-27_decoder_confidence_dprime_by_block_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649944_2023-02-27_decoder_confidence_dprime_by_block_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649944_2023-02-27_decoder_confidence_versus_response_type.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649944_2023-02-27_decoder_confidence_versus_response_type.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649944_2023-02-27_decoder_confidence_versus_response_type_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649944_2023-02-27_decoder_confidence_versus_response_type_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649944_2023-02-27_decoder_confidence_versus_trials_since_rewarded_target.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649944_2023-02-27_decoder_confidence_versus_trials_since_rewarded_target.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649944_2023-02-27_decoder_confidence_versus_trials_since_rewarded_target_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649944_2023-02-27_decoder_confidence_versus_trials_since_rewarded_target_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649944_2023-02-27_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649944_2023-02-28_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649944_2023-02-28_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/660023_2023-08-09_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/660023_2023-08-09_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-21_1_21_2025.json
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-21_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-21_decoder_confidence_all_trials.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-21_decoder_confidence_all_trials.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-21_decoder_confidence_all_trials_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-21_decoder_confidence_all_trials_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-21_decoder_confidence_before_after_target.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-21_decoder_confidence_before_after_target.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-21_decoder_confidence_before_after_target_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-21_decoder_confidence_before_after_target_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-21_decoder_confidence_by_switch.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-21_decoder_confidence_by_switch.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-21_decoder_confidence_by_switch_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-21_decoder_confidence_by_switch_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-21_decoder_confidence_dprime_by_block.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-21_decoder_confidence_dprime_by_block.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-21_decoder_confidence_dprime_by_block_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-21_decoder_confidence_dprime_by_block_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-21_decoder_confidence_versus_response_type.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-21_decoder_confidence_versus_response_type.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-21_decoder_confidence_versus_response_type_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-21_decoder_confidence_versus_response_type_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-21_decoder_confidence_versus_trials_since_rewarded_target.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-21_decoder_confidence_versus_trials_since_rewarded_target.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-21_decoder_confidence_versus_trials_since_rewarded_target_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-21_decoder_confidence_versus_trials_since_rewarded_target_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-21_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-22_1_21_2025.json
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-22_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-22_decoder_confidence_all_trials.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-22_decoder_confidence_all_trials.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-22_decoder_confidence_all_trials_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-22_decoder_confidence_all_trials_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-22_decoder_confidence_before_after_target.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-22_decoder_confidence_before_after_target.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-22_decoder_confidence_before_after_target_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-22_decoder_confidence_before_after_target_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-22_decoder_confidence_by_switch.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-22_decoder_confidence_by_switch.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-22_decoder_confidence_by_switch_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-22_decoder_confidence_by_switch_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-22_decoder_confidence_dprime_by_block.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-22_decoder_confidence_dprime_by_block.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-22_decoder_confidence_dprime_by_block_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-22_decoder_confidence_dprime_by_block_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-22_decoder_confidence_versus_response_type.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-22_decoder_confidence_versus_response_type.pkl
# ...
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/715710_2024-07-15_decoder_confidence_versus_response_type.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/715710_2024-07-15_decoder_confidence_versus_response_type_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/715710_2024-07-15_decoder_confidence_versus_response_type_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/715710_2024-07-15_decoder_confidence_versus_trials_since_rewarded_target.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/715710_2024-07-15_decoder_confidence_versus_trials_since_rewarded_target.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/715710_2024-07-15_decoder_confidence_versus_trials_since_rewarded_target_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/715710_2024-07-15_decoder_confidence_versus_trials_since_rewarded_target_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/715710_2024-07-15_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/715710_2024-07-17_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/715710_2024-07-17_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/715710_2024-07-18_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/715710_2024-07-18_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/715710_2024-07-19_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/715710_2024-07-19_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-17_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-17_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-18_1_21_2025.json
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-18_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-18_decoder_confidence_all_trials.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-18_decoder_confidence_all_trials.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-18_decoder_confidence_all_trials_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-18_decoder_confidence_all_trials_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-18_decoder_confidence_before_after_target.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-18_decoder_confidence_before_after_target.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-18_decoder_confidence_before_after_target_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-18_decoder_confidence_before_after_target_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-18_decoder_confidence_by_switch.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-18_decoder_confidence_by_switch.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-18_decoder_confidence_by_switch_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-18_decoder_confidence_by_switch_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-18_decoder_confidence_dprime_by_block.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-18_decoder_confidence_dprime_by_block.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-18_decoder_confidence_dprime_by_block_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-18_decoder_confidence_dprime_by_block_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-18_decoder_confidence_versus_response_type.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-18_decoder_confidence_versus_response_type.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-18_decoder_confidence_versus_response_type_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-18_decoder_confidence_versus_response_type_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-18_decoder_confidence_versus_trials_since_rewarded_target.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-18_decoder_confidence_versus_trials_since_rewarded_target.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-18_decoder_confidence_versus_trials_since_rewarded_target_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-18_decoder_confidence_versus_trials_since_rewarded_target_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-18_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-20_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-20_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-21_1_21_2025.json
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-21_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-21_decoder_confidence_all_trials.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-21_decoder_confidence_all_trials.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-21_decoder_confidence_all_trials_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-21_decoder_confidence_all_trials_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-21_decoder_confidence_before_after_target.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-21_decoder_confidence_before_after_target.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-21_decoder_confidence_before_after_target_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-21_decoder_confidence_before_after_target_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-21_decoder_confidence_by_switch.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-21_decoder_confidence_by_switch.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-21_decoder_confidence_by_switch_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-21_decoder_confidence_by_switch_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-21_decoder_confidence_dprime_by_block.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-21_decoder_confidence_dprime_by_block.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-21_decoder_confidence_dprime_by_block_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-21_decoder_confidence_dprime_by_block_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-21_decoder_confidence_versus_response_type.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-21_decoder_confidence_versus_response_type.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-21_decoder_confidence_versus_response_type_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-21_decoder_confidence_versus_response_type_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-21_decoder_confidence_versus_trials_since_rewarded_target.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-21_decoder_confidence_versus_trials_since_rewarded_target.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-21_decoder_confidence_versus_trials_since_rewarded_target_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-21_decoder_confidence_versus_trials_since_rewarded_target_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-21_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733780_2024-09-04_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733780_2024-09-04_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733780_2024-09-05_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733780_2024-09-05_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733780_2024-09-06_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733780_2024-09-06_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-16_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-16_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-17_1_21_2025.json
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-17_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-17_decoder_confidence_all_trials.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-17_decoder_confidence_all_trials.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-17_decoder_confidence_all_trials_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-17_decoder_confidence_all_trials_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-17_decoder_confidence_before_after_target.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-17_decoder_confidence_before_after_target.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-17_decoder_confidence_before_after_target_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-17_decoder_confidence_before_after_target_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-17_decoder_confidence_by_switch.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-17_decoder_confidence_by_switch.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-17_decoder_confidence_by_switch_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-17_decoder_confidence_by_switch_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-17_decoder_confidence_dprime_by_block.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-17_decoder_confidence_dprime_by_block.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-17_decoder_confidence_dprime_by_block_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-17_decoder_confidence_dprime_by_block_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-17_decoder_confidence_versus_response_type.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-17_decoder_confidence_versus_response_type.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-17_decoder_confidence_versus_response_type_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-17_decoder_confidence_versus_response_type_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-17_decoder_confidence_versus_trials_since_rewarded_target.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-17_decoder_confidence_versus_trials_since_rewarded_target.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-17_decoder_confidence_versus_trials_since_rewarded_target_all_units.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-17_decoder_confidence_versus_trials_since_rewarded_target_all_units.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-17_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-18_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-18_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-19_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-19_linear_shift_decoding_results.csv
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/737403_2024-09-24_1_21_2025.pkl
# s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/737403_2024-09-24_linear_shift_decoding_results.csv

# %%
import pandas as pd

pd.read_csv(csvs[11])
# Out:
#    Unnamed: 0         session_id         project  area  ccf_ap_mean  \
# 0           0  644864_2023-02-02  DynamicRouting     0          NaN
#
#    ccf_dv_mean  ccf_ml_mean  n_units  probe  cross_modal_dprime  \
# 0          NaN          NaN      NaN    NaN             2.36721
#
#    n_good_blocks  true_accuracy_all  null_accuracy_mean_all  \
# 0              6           0.805391                0.672626
#
#    null_accuracy_median_all  null_accuracy_std_all  p_value_all  \
# 0                  0.675291               0.082902     0.026316
#
#    true_accuracy_all_trials_no_shift_all
# 0                               0.811249

# %%
csvs[0]
# Out:
# S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620263_2022-07-26_linear_shift_decoding_results.csv')

# %%
# savepath=r'D:\decoding_results_from_CO\n_units_test_2024-11-06'
# savepath=r'D:\decoding_results_from_CO\n_units_test_medium_unit_criteria_2024-11-07'
# savepath=r'D:\decoding_results_from_CO\lda_test_2024-11-11'
# savepath=r'D:\decoding_results_from_CO\logreg_test_2024-11-13'
# savepath=r'D:\decoding_results_from_CO\ben_test_12-12'
# savepath=r'D:\decoding_results_from_CO\logreg_many_n_units_2024_12_17'
# savepath=r'D:\decoding_results_from_CO\logreg_many_n_units_strict_criteria_2024_12_19'
# savepath=r'D:\decoding_results_from_CO\logreg_many_n_units_medium_criteria_2024_12_18'
savepath=r'D:\decoding_results_from_CO\logreg_many_n_units_sliding_rp_criteria_2024-12-20'

decoding_utils.concat_decoder_summary_tables(path,savepath)

# %%
csvs
# Out:
# [S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620263_2022-07-26_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620263_2022-07-27_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/620264_2022-08-02_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-15_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-16_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/626791_2022-08-17_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/628801_2022-09-19_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636397_2022-09-26_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636397_2022-09-27_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636766_2023-01-23_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/636766_2023-01-24_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644864_2023-02-02_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-07_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-08_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-09_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644866_2023-02-10_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644867_2023-02-20_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644867_2023-02-22_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/644867_2023-02-23_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/646318_2023-01-17_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649943_2023-02-13_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649943_2023-02-14_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649943_2023-02-15_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649943_2023-02-16_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649944_2023-02-27_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/649944_2023-02-28_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/660023_2023-08-09_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-21_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-22_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-23_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662892_2023-08-24_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/662983_2023-05-15_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/664851_2023-11-13_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/664851_2023-11-14_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/664851_2023-11-15_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/664851_2023-11-16_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/666986_2023-08-14_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/666986_2023-08-15_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/666986_2023-08-17_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/667252_2023-09-26_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/667252_2023-09-28_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/668755_2023-08-28_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/668755_2023-08-29_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/668755_2023-08-30_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/668755_2023-08-31_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/670180_2023-07-26_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/670180_2023-07-27_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/670248_2023-08-01_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/674562_2023-10-02_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/674562_2023-10-03_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/674562_2023-10-04_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/674562_2023-10-05_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/676909_2023-12-11_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/676909_2023-12-12_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/676909_2023-12-13_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/676909_2023-12-14_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/681532_2023-10-16_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/681532_2023-10-17_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/681532_2023-10-18_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/686176_2023-12-04_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/686176_2023-12-05_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/686176_2023-12-07_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/686740_2023-10-23_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/686740_2023-10-24_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/686740_2023-10-25_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/690706_2023-11-27_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/690706_2023-11-28_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/690706_2023-11-29_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/690706_2023-11-30_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/699847_2024-04-15_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/699847_2024-04-16_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/699847_2024-04-17_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/699847_2024-04-18_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/702131_2024-02-26_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/702136_2024-03-04_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/702136_2024-03-05_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/702136_2024-03-06_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/702136_2024-03-07_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/703333_2024-04-08_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/703333_2024-04-09_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/703333_2024-04-10_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/703333_2024-04-11_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/703880_2024-04-15_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/703880_2024-04-16_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/703880_2024-04-17_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/703880_2024-04-18_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/703882_2024-04-22_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/703882_2024-04-24_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/703882_2024-04-25_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/706401_2024-04-23_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/706401_2024-04-24_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/708016_2024-04-29_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/708016_2024-04-30_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/708016_2024-05-01_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/712815_2024-05-22_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/712815_2024-05-23_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/713655_2024-08-09_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/714748_2024-06-24_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/714748_2024-06-25_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/714748_2024-06-26_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/714748_2024-06-27_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/714753_2024-07-01_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/714753_2024-07-02_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/715710_2024-07-15_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/715710_2024-07-17_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/715710_2024-07-18_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/715710_2024-07-19_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-17_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-18_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-20_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/726088_2024-06-21_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733780_2024-09-04_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733780_2024-09-05_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733780_2024-09-06_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-16_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-17_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-18_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/733891_2024-09-19_linear_shift_decoding_results.csv'),
#  S3Path('s3://aind-scratch-data/dynamic-routing/ethan/decoding-results/test/test_1_21_2025/737403_2024-09-24_linear_shift_decoding_results.csv')]

# %%
logfiledir = r"D:\decoding_results_from_CO\logs\logs_medium_criteria_run_12_18"

check_strs=['ERROR','Traceback']

#load each file in directory, and check if these strings are in the text
# if they are, print the name of the file

for file in upath.UPath(logfiledir).glob('*'):
    if file.is_file():
        with open(file, 'r') as f:
            text = f.read()
            if any(check_str in text for check_str in check_strs):
                print(file.name)
                
                #find where in the file the error or traceback is:
                for check_str in check_strs:
                    if check_str in text:
                        print('\n'+text[text.find(check_str)-100:text.find(check_str)+len(check_str)+2000])
# Out:
# 014f47b5-0770-494c-aaa2-d8bfd1dea981.log
#
# shift | 668755_2023-08-29 | Parameters parsed. Starting decoding analysis
# 2024-18-12 16:04:53 PST | ERROR | 014f47b5.run_capsule.main | 668755_2023-08-29 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.Fxi8YtKCDZ/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.Fxi8YtKCDZ/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.Fxi8YtKCDZ/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.Fxi8YtKCDZ/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:04:53 PST | INFO | 014f47b5.run_capsule.main | Time elapsed: 100.82 s
#
#
#  analysis
# 2024-18-12 16:04:53 PST | ERROR | 014f47b5.run_capsule.main | 668755_2023-08-29 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.Fxi8YtKCDZ/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.Fxi8YtKCDZ/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.Fxi8YtKCDZ/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.Fxi8YtKCDZ/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:04:53 PST | INFO | 014f47b5.run_capsule.main | Time elapsed: 100.82 s
#
# 043f19cd-0374-4322-bbea-8000b1f094a1.log
#
# shift | 681532_2023-10-17 | Parameters parsed. Starting decoding analysis
# 2024-18-12 16:12:52 PST | ERROR | 043f19cd.run_capsule.main | 681532_2023-10-17 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.9eCes2ILtl/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.9eCes2ILtl/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.9eCes2ILtl/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.9eCes2ILtl/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:12:52 PST | INFO | 043f19cd.run_capsule.main | Time elapsed: 149.59 s
#
#
#  analysis
# 2024-18-12 16:12:52 PST | ERROR | 043f19cd.run_capsule.main | 681532_2023-10-17 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.9eCes2ILtl/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.9eCes2ILtl/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.9eCes2ILtl/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.9eCes2ILtl/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:12:52 PST | INFO | 043f19cd.run_capsule.main | Time elapsed: 149.59 s
#
# 06306240-201e-488e-a1c5-ce7750916d6a.log
#
# shift | 644547_2022-12-06 | Parameters parsed. Starting decoding analysis
# 2024-18-12 16:09:56 PST | ERROR | 06306240.run_capsule.main | 644547_2022-12-06 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.RnE7H1gGhI/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.RnE7H1gGhI/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.RnE7H1gGhI/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.RnE7H1gGhI/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:09:56 PST | INFO | 06306240.run_capsule.main | Time elapsed: 67.68 s
#
#
#  analysis
# 2024-18-12 16:09:56 PST | ERROR | 06306240.run_capsule.main | 644547_2022-12-06 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.RnE7H1gGhI/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.RnE7H1gGhI/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.RnE7H1gGhI/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.RnE7H1gGhI/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:09:56 PST | INFO | 06306240.run_capsule.main | Time elapsed: 67.68 s
#
# 075bae6c-8b8f-49f7-9064-cb2007e23e04.log
#
# shift | 636397_2022-09-27 | Parameters parsed. Starting decoding analysis
# 2024-18-12 16:24:54 PST | ERROR | 075bae6c.run_capsule.main | 636397_2022-09-27 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.rU4nIL3Fqx/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.rU4nIL3Fqx/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.rU4nIL3Fqx/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.rU4nIL3Fqx/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:24:54 PST | INFO | 075bae6c.run_capsule.main | Time elapsed: 69.57 s
#
#
#  analysis
# 2024-18-12 16:24:54 PST | ERROR | 075bae6c.run_capsule.main | 636397_2022-09-27 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.rU4nIL3Fqx/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.rU4nIL3Fqx/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.rU4nIL3Fqx/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.rU4nIL3Fqx/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:24:54 PST | INFO | 075bae6c.run_capsule.main | Time elapsed: 69.57 s
#
# 10ec3ba5-20a2-48f1-86ac-14eed2f57889.log
#
# shift | 703880_2024-04-16 | Parameters parsed. Starting decoding analysis
# 2024-18-12 16:08:40 PST | ERROR | 10ec3ba5.run_capsule.main | 703880_2024-04-16 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.yXqlBRsI4n/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.yXqlBRsI4n/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.yXqlBRsI4n/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.yXqlBRsI4n/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:08:40 PST | INFO | 10ec3ba5.run_capsule.main | Time elapsed: 84.94 s
#
#
#  analysis
# 2024-18-12 16:08:40 PST | ERROR | 10ec3ba5.run_capsule.main | 703880_2024-04-16 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.yXqlBRsI4n/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.yXqlBRsI4n/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.yXqlBRsI4n/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.yXqlBRsI4n/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:08:40 PST | INFO | 10ec3ba5.run_capsule.main | Time elapsed: 84.94 s
#
# 173d2b70-b0dc-4227-ae88-ad9cd272745d.log
#
# shift | 712815_2024-05-22 | Parameters parsed. Starting decoding analysis
# 2024-18-12 16:10:46 PST | ERROR | 173d2b70.run_capsule.main | 712815_2024-05-22 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.iPt6WrJ5Zg/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.iPt6WrJ5Zg/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.iPt6WrJ5Zg/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.iPt6WrJ5Zg/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:10:46 PST | INFO | 173d2b70.run_capsule.main | Time elapsed: 54.31 s
#
#
#  analysis
# 2024-18-12 16:10:46 PST | ERROR | 173d2b70.run_capsule.main | 712815_2024-05-22 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.iPt6WrJ5Zg/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.iPt6WrJ5Zg/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.iPt6WrJ5Zg/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.iPt6WrJ5Zg/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:10:46 PST | INFO | 173d2b70.run_capsule.main | Time elapsed: 54.31 s
#
# 21e7edd7-f917-4e64-82bb-e2fd16dd44ed.log
#
# shift | 737403_2024-09-27 | Parameters parsed. Starting decoding analysis
# 2024-18-12 16:27:06 PST | ERROR | 21e7edd7.run_capsule.main | 737403_2024-09-27 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.4HkXP1FKcj/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.4HkXP1FKcj/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.4HkXP1FKcj/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.4HkXP1FKcj/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:27:06 PST | INFO | 21e7edd7.run_capsule.main | Time elapsed: 138.60 s
#
#
#  analysis
# 2024-18-12 16:27:06 PST | ERROR | 21e7edd7.run_capsule.main | 737403_2024-09-27 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.4HkXP1FKcj/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.4HkXP1FKcj/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.4HkXP1FKcj/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.4HkXP1FKcj/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:27:06 PST | INFO | 21e7edd7.run_capsule.main | Time elapsed: 138.60 s
#
# 3829c0a0-5f37-4012-bf6d-01c0c40dac87.log
#
# shift | 733780_2024-09-05 | Parameters parsed. Starting decoding analysis
# 2024-18-12 16:25:39 PST | ERROR | 3829c0a0.run_capsule.main | 733780_2024-09-05 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.XIsL1Scf9V/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.XIsL1Scf9V/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.XIsL1Scf9V/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.XIsL1Scf9V/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:25:39 PST | INFO | 3829c0a0.run_capsule.main | Time elapsed: 85.08 s
#
#
#  analysis
# 2024-18-12 16:25:39 PST | ERROR | 3829c0a0.run_capsule.main | 733780_2024-09-05 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.XIsL1Scf9V/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.XIsL1Scf9V/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.XIsL1Scf9V/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.XIsL1Scf9V/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:25:39 PST | INFO | 3829c0a0.run_capsule.main | Time elapsed: 85.08 s
#
# 38fd6f3a-c6e1-4580-8850-a469f0954d57.log
#
# shift | 664851_2023-11-15 | Parameters parsed. Starting decoding analysis
# 2024-18-12 16:16:21 PST | ERROR | 38fd6f3a.run_capsule.main | 664851_2023-11-15 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.dsuCZtvUW6/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.dsuCZtvUW6/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.dsuCZtvUW6/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.dsuCZtvUW6/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:16:21 PST | INFO | 38fd6f3a.run_capsule.main | Time elapsed: 112.80 s
#
#
#  analysis
# 2024-18-12 16:16:21 PST | ERROR | 38fd6f3a.run_capsule.main | 664851_2023-11-15 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.dsuCZtvUW6/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.dsuCZtvUW6/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.dsuCZtvUW6/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.dsuCZtvUW6/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:16:21 PST | INFO | 38fd6f3a.run_capsule.main | Time elapsed: 112.80 s
#
# 3c7722ea-9cb6-4797-a672-73fedc82e90e.log
#
# shift | 649943_2023-02-16 | Parameters parsed. Starting decoding analysis
# 2024-18-12 16:20:08 PST | ERROR | 3c7722ea.run_capsule.main | 649943_2023-02-16 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.Al0PWLlsMR/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.Al0PWLlsMR/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.Al0PWLlsMR/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.Al0PWLlsMR/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:20:08 PST | INFO | 3c7722ea.run_capsule.main | Time elapsed: 91.58 s
#
#
#  analysis
# 2024-18-12 16:20:08 PST | ERROR | 3c7722ea.run_capsule.main | 649943_2023-02-16 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.Al0PWLlsMR/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.Al0PWLlsMR/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.Al0PWLlsMR/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.Al0PWLlsMR/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:20:08 PST | INFO | 3c7722ea.run_capsule.main | Time elapsed: 91.58 s
#
# 4187a156-ee98-4d8c-98d0-3d25dc522c69.log
#
# shift | 699847_2024-04-17 | Parameters parsed. Starting decoding analysis
# 2024-18-12 16:18:51 PST | ERROR | 4187a156.run_capsule.main | 699847_2024-04-17 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.IjLoUIbPMo/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.IjLoUIbPMo/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.IjLoUIbPMo/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.IjLoUIbPMo/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:18:51 PST | INFO | 4187a156.run_capsule.main | Time elapsed: 112.21 s
#
#
#  analysis
# 2024-18-12 16:18:51 PST | ERROR | 4187a156.run_capsule.main | 699847_2024-04-17 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.IjLoUIbPMo/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.IjLoUIbPMo/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.IjLoUIbPMo/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.IjLoUIbPMo/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:18:51 PST | INFO | 4187a156.run_capsule.main | Time elapsed: 112.21 s
#
# 43ac09fa-7370-40bc-a7a0-70a1bd5a5eb1.log
#
# shift | 674562_2023-10-03 | Parameters parsed. Starting decoding analysis
# 2024-18-12 16:15:15 PST | ERROR | 43ac09fa.run_capsule.main | 674562_2023-10-03 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.s7j6lobKx9/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.s7j6lobKx9/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.s7j6lobKx9/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.s7j6lobKx9/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:15:15 PST | INFO | 43ac09fa.run_capsule.main | Time elapsed: 78.65 s
#
#
#  analysis
# 2024-18-12 16:15:15 PST | ERROR | 43ac09fa.run_capsule.main | 674562_2023-10-03 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.s7j6lobKx9/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.s7j6lobKx9/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.s7j6lobKx9/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.s7j6lobKx9/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:15:15 PST | INFO | 43ac09fa.run_capsule.main | Time elapsed: 78.65 s
#
# 44025cb2-cade-452e-b382-e9c2f37a7a57.log
#
# shift | 715710_2024-07-18 | Parameters parsed. Starting decoding analysis
# 2024-18-12 16:11:45 PST | ERROR | 44025cb2.run_capsule.main | 715710_2024-07-18 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.fsxbOfdsfe/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.fsxbOfdsfe/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.fsxbOfdsfe/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.fsxbOfdsfe/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:11:45 PST | INFO | 44025cb2.run_capsule.main | Time elapsed: 144.07 s
#
#
#  analysis
# 2024-18-12 16:11:45 PST | ERROR | 44025cb2.run_capsule.main | 715710_2024-07-18 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.fsxbOfdsfe/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.fsxbOfdsfe/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.fsxbOfdsfe/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.fsxbOfdsfe/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:11:45 PST | INFO | 44025cb2.run_capsule.main | Time elapsed: 144.07 s
#
# 4adb84cc-2e31-4ba7-9be3-b3c9ca1892aa.log
#
# shift | 741137_2024-10-10 | Parameters parsed. Starting decoding analysis
# 2024-18-12 16:14:58 PST | ERROR | 4adb84cc.run_capsule.main | 741137_2024-10-10 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.7aIA9sPR8c/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.7aIA9sPR8c/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.7aIA9sPR8c/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.7aIA9sPR8c/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:14:58 PST | INFO | 4adb84cc.run_capsule.main | Time elapsed: 47.43 s
#
#
#  analysis
# 2024-18-12 16:14:58 PST | ERROR | 4adb84cc.run_capsule.main | 741137_2024-10-10 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.7aIA9sPR8c/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.7aIA9sPR8c/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.7aIA9sPR8c/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.7aIA9sPR8c/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:14:58 PST | INFO | 4adb84cc.run_capsule.main | Time elapsed: 47.43 s
#
# 4c42d5a7-7be3-4e93-ba48-82a02f8bcad4.log
#
# shift | 726088_2024-06-20 | Parameters parsed. Starting decoding analysis
# 2024-18-12 16:05:28 PST | ERROR | 4c42d5a7.run_capsule.main | 726088_2024-06-20 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.eV5XadhvMt/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.eV5XadhvMt/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.eV5XadhvMt/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
# ...
#   File "/tmp/nxf.hJpDOqqTJ8/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:16:11 PST | INFO | f39770a9.run_capsule.main | Time elapsed: 27.23 s
#
#
#  analysis
# 2024-18-12 16:16:11 PST | ERROR | f39770a9.run_capsule.main | 708016_2024-04-30 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.hJpDOqqTJ8/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.hJpDOqqTJ8/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.hJpDOqqTJ8/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.hJpDOqqTJ8/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:16:11 PST | INFO | f39770a9.run_capsule.main | Time elapsed: 27.23 s
#
# f4088a67-2bb8-4cf0-bb3b-7fe34e31df53.log
#
# shift | 702136_2024-03-07 | Parameters parsed. Starting decoding analysis
# 2024-18-12 16:08:36 PST | ERROR | f4088a67.run_capsule.main | 702136_2024-03-07 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.5uqJSzOxfU/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.5uqJSzOxfU/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.5uqJSzOxfU/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.5uqJSzOxfU/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:08:36 PST | INFO | f4088a67.run_capsule.main | Time elapsed: 78.63 s
#
#
#  analysis
# 2024-18-12 16:08:36 PST | ERROR | f4088a67.run_capsule.main | 702136_2024-03-07 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.5uqJSzOxfU/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.5uqJSzOxfU/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.5uqJSzOxfU/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.5uqJSzOxfU/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:08:36 PST | INFO | f4088a67.run_capsule.main | Time elapsed: 78.63 s
#
# f7a71081-1e51-4e2a-89cd-baac2bf825e0.log
#
# shift | 742903_2024-10-21 | Parameters parsed. Starting decoding analysis
# 2024-18-12 16:07:43 PST | ERROR | f7a71081.run_capsule.main | 742903_2024-10-21 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.BjnGql5pIk/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.BjnGql5pIk/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.BjnGql5pIk/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.BjnGql5pIk/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:07:43 PST | INFO | f7a71081.run_capsule.main | Time elapsed: 57.12 s
#
#
#  analysis
# 2024-18-12 16:07:43 PST | ERROR | f7a71081.run_capsule.main | 742903_2024-10-21 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.BjnGql5pIk/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.BjnGql5pIk/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.BjnGql5pIk/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.BjnGql5pIk/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:07:43 PST | INFO | f7a71081.run_capsule.main | Time elapsed: 57.12 s
#
# fc36da04-2de2-4866-85a9-52f6822e315f.log
#
# shift | 626791_2022-08-16 | Parameters parsed. Starting decoding analysis
# 2024-18-12 16:21:16 PST | ERROR | fc36da04.run_capsule.main | 626791_2022-08-16 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.iVZBVPL36P/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.iVZBVPL36P/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.iVZBVPL36P/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.iVZBVPL36P/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:21:16 PST | INFO | fc36da04.run_capsule.main | Time elapsed: 25.47 s
#
#
#  analysis
# 2024-18-12 16:21:16 PST | ERROR | fc36da04.run_capsule.main | 626791_2022-08-16 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.iVZBVPL36P/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.iVZBVPL36P/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.iVZBVPL36P/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.iVZBVPL36P/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:21:16 PST | INFO | fc36da04.run_capsule.main | Time elapsed: 25.47 s
#
# ff9ae162-3464-4b73-b783-80cc5f355026.log
#
# shift | 620263_2022-07-26 | Parameters parsed. Starting decoding analysis
# 2024-18-12 16:21:13 PST | ERROR | ff9ae162.run_capsule.main | 620263_2022-07-26 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.9UBV74ioqz/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.9UBV74ioqz/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.9UBV74ioqz/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.9UBV74ioqz/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:21:13 PST | INFO | ff9ae162.run_capsule.main | Time elapsed: 65.41 s
#
#
#  analysis
# 2024-18-12 16:21:13 PST | ERROR | ff9ae162.run_capsule.main | 620263_2022-07-26 | Failed:
# Traceback (most recent call last):
#   File "/tmp/nxf.9UBV74ioqz/capsule/code/run_capsule.py", line 307, in main
#     process_session(session_id, params=Params(**params | {'session_id': session_id}), test=args.test, skip_existing=args.skip_existing)
#   File "/tmp/nxf.9UBV74ioqz/capsule/code/run_capsule.py", line 130, in process_session
#     decoding_utils.decode_context_with_linear_shift(session=session,params=params.to_dict(),trials=trials,units=units)
#   File "/tmp/nxf.9UBV74ioqz/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 1205, in decode_context_with_linear_shift
#     decoder_results[session_id]['results'][aa]['no_shift'][nunits][rr] = decoder_helper(
#   File "/tmp/nxf.9UBV74ioqz/capsule/code/dynamic_routing_analysis/src/dynamic_routing_analysis/decoding_utils.py", line 218, in decoder_helper
#     clf.fit(X[train],y[train])
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'C' parameter of LogisticRegression must be a float in the range (0.0, inf]. Got None instead.
# 2024-18-12 16:21:13 PST | INFO | ff9ae162.run_capsule.main | Time elapsed: 65.41 s
