# %%
import sys
sys.path.append(r"C:\Users\shailaja.akella\Dropbox (Personal)\DR\dynamic_routing_analysis_ethan\src")

import npc_lims
from dynamic_routing_analysis import decoding_utils
from npc_sessions import DynamicRoutingSession
import numpy as np
import matplotlib.pyplot as plt

# %%
#1A get all uploaded & annotated ephys sessions
ephys_sessions = tuple(s for s in npc_lims.get_session_info(is_ephys=True, is_uploaded=True, is_annotated=True))

# %%
# 2 set savepath and filename
savepath = r"C:\Users\shailaja.akella\Dropbox (Personal)\DR\dynamic_routing_analysis_ethan\results\facemap/"
filename = 'decoding_results_linear_shift_facemap.pkl'

except_list = {}

# 3 set parameters
# linear shift decoding currently just takes the average firing rate over all bins defined here
spikes_binsize = 0.2  # bin size in seconds
spikes_time_before = 0.2  # time before the stimulus per trial
spikes_time_after = 0.01  # time after the stimulus per trial

# #not used for linear shift decoding, were used in a previous iteration of decoding analysis
# decoder_binsize=0.2
# decoder_time_before=0.2
# decoder_time_after=0.1

params = {
    'n_units': 20,  # number of units to sample for each area
    'n_repeats': 25,  # number of times to repeat decoding with different randomly sampled units
    'input_data_type': 'facemap',  # spikes or facemap or LP
    'vid_angle_facemotion': 'face', # behavior, face, eye
    'vid_angle_LP': 'behavior',
    'central_section': '4_blocks_plus',
    # for linear shift decoding, how many trials to use for the shift. '4_blocks_plus' is best
    'exclude_cue_trials': False,  # option to totally exclude autorewarded trials
    'n_unit_threshold': 20,  # minimum number of units to include an area in the analysis
    'keep_n_SVDs': 500,  # number of SVD components to keep for facemap data
    'LP_parts_to_keep': ['ear_base_l', 'eye_bottom_l', 'jaw', 'nose_tip', 'whisker_pad_l_side'],
    'spikes_binsize': spikes_binsize,
    'spikes_time_before': spikes_time_before,
    'spikes_time_after': spikes_time_after,
    # 'decoder_binsize':decoder_binsize,
    # 'decoder_time_before':decoder_time_before,
    # 'decoder_time_after':decoder_time_after,
    'savepath': savepath,
    'filename': filename,
    'use_structure_probe': True,  # if True, appedn probe name to area name when multiple probes in the same area
    'crossval': '5_fold',  # '5_fold' or 'blockwise' - blockwise untested with linear shift
    'labels_as_index': True,  # convert labels (context names) to index [0,1]
    'decoder_type': 'linearSVC',  # 'linearSVC' or 'LDA' or 'RandomForest' or 'LogisticRegression'
}


for ephys_session in ephys_sessions[:]:
    try:
        session = DynamicRoutingSession(ephys_session)
        print(session.id + ' loaded')
        if 'structure' in session.electrodes[:].columns:
            decoding_utils.decode_context_with_linear_shift(session, params)
        else:
            print('no structure column found in electrodes table, moving to next recording')
        session = []
    except Exception as e:
        except_list[session.id] = repr(e)
# Out:
# 714748_2024-06-27_0 loaded
# probe_insertions.json and annotation info do not match for 714748_2024-06-27 - using annotation info
# no cached trials table, using npc_sessions
# finished 714748_2024-06-27 0
# finished 714748_2024-06-27
# 714748_2024-06-26_0 loaded
# probe_insertions.json and annotation info do not match for 714748_2024-06-26 - using annotation info
# no cached trials table, using npc_sessions
# finished 714748_2024-06-26 0
# finished 714748_2024-06-26
# 714748_2024-06-24_0 loaded
# probe_insertions.json and annotation info do not match for 714748_2024-06-24 - using annotation info
# no cached trials table, using npc_sessions
# finished 714748_2024-06-24 0
# finished 714748_2024-06-24
# 726088_2024-06-21_0 loaded
# probe_insertions.json and annotation info do not match for 726088_2024-06-21 - using annotation info
# no cached trials table, using npc_sessions
# finished 726088_2024-06-21 0
# finished 726088_2024-06-21
# 726088_2024-06-20_0 loaded
# probe_insertions.json and annotation info do not match for 726088_2024-06-20 - using annotation info
# no cached trials table, using npc_sessions
# Stim block_idx=3 has len(diode_flips)=214398 diode flips, len(vsyncs)=217127 vsyncs:too great a difference to correct. Returning display times based on vsync + constant lag.
# finished 726088_2024-06-20 0
# finished 726088_2024-06-20
# 726088_2024-06-18_0 loaded
# probe_insertions.json and annotation info do not match for 726088_2024-06-18 - using annotation info
# no cached trials table, using npc_sessions
# stim_running block [1624.21:1624.23] has 1 vsync(s) - excluding from analysis
# No lick time found within response window on sync for trial 330, despite being marked as a response trial.
# finished 726088_2024-06-18 0
# finished 726088_2024-06-18
# 726088_2024-06-17_0 loaded
# probe_insertions.json and annotation info do not match for 726088_2024-06-17 - using annotation info
# no cached trials table, using npc_sessions
# finished 726088_2024-06-17 0
# finished 726088_2024-06-17
# 712815_2024-05-23_0 loaded
# probe_insertions.json and annotation info do not match for 712815_2024-05-23 - using annotation info
# no cached trials table, using npc_sessions
# Stim block_idx=3 has len(diode_flips)=213725 diode flips, len(vsyncs)=217159 vsyncs:too great a difference to correct. Returning display times based on vsync + constant lag.
# finished 712815_2024-05-23 0
# finished 712815_2024-05-23
# 712815_2024-05-22_0 loaded
# probe_insertions.json and annotation info do not match for 712815_2024-05-22 - using annotation info
# no cached trials table, using npc_sessions
# finished 712815_2024-05-22 0
# finished 712815_2024-05-22
# 712815_2024-05-21_0 loaded
# probe_insertions.json and annotation info do not match for 712815_2024-05-21 - using annotation info
# no cached trials table, using npc_sessions
# Camera lines are plugged into sync incorrectly - we'll accommodate for this, but if this is a recent session check the rig: {'behavior': 'beh', 'face': 'eye', 'eye': 'face'}
# finished 712815_2024-05-21 0
# finished 712815_2024-05-21
# Session 712815_2024-05-20 has known issues: ['https://github.com/AllenInstitute/npc_sessions/issues/96', 'https://github.com/AllenInstitute/npc_sessions/issues/100']
# 712815_2024-05-20_0 loaded
# Camera lines are plugged into sync incorrectly - we'll accommodate for this, but if this is a recent session check the rig: {'behavior': 'beh', 'face': 'eye', 'eye': 'face'}
# Session 708016_2024-05-02 has known issues: ['https://github.com/AllenInstitute/npc_sessions/issues/92']
# 708016_2024-05-02_0 loaded
# no cached trials table, using npc_sessions
# Camera lines are plugged into sync incorrectly - we'll accommodate for this, but if this is a recent session check the rig: {'behavior': 'beh', 'face': 'eye', 'eye': 'face'}
# finished 708016_2024-05-02 0
# finished 708016_2024-05-02
# 708016_2024-05-01_0 loaded
# no cached trials table, using npc_sessions
# Camera lines are plugged into sync incorrectly - we'll accommodate for this, but if this is a recent session check the rig: {'behavior': 'beh', 'face': 'eye', 'eye': 'face'}
# finished 708016_2024-05-01 0
# finished 708016_2024-05-01
# 708016_2024-04-30_0 loaded
# probe_insertions.json and annotation info do not match for 708016_2024-04-30 - using annotation info
# no cached trials table, using npc_sessions
# Mismatch in stim block_idx = 0: len(diode_flips) = 51338, len(vsyncs) = 51339
# Returning display times based on vsync + constanst lag for block_idx=0.
# Camera lines are plugged into sync incorrectly - we'll accommodate for this, but if this is a recent session check the rig: {'behavior': 'beh', 'face': 'eye', 'eye': 'face'}
# finished 708016_2024-04-30 0
# finished 708016_2024-04-30
# Session 708016_2024-04-29 has known issues: ['https://github.com/AllenInstitute/npc_sessions/issues/101', 'https://github.com/AllenInstitute/npc_sessions/issues/108']
# 708016_2024-04-29_0 loaded
# probe_insertions.json and annotation info do not match for 708016_2024-04-29 - using annotation info
# no cached trials table, using npc_sessions
# Camera lines are plugged into sync incorrectly - we'll accommodate for this, but if this is a recent session check the rig: {'behavior': 'beh', 'face': 'eye', 'eye': 'face'}
# finished 708016_2024-04-29 0
# finished 708016_2024-04-29
# 703882_2024-04-25_0 loaded
# probe_insertions.json and annotation info do not match for 703882_2024-04-25 - using annotation info
# no cached trials table, using npc_sessions
# Camera lines are plugged into sync incorrectly - we'll accommodate for this, but if this is a recent session check the rig: {'behavior': 'beh', 'face': 'eye', 'eye': 'face'}
# finished 703882_2024-04-25 0
# finished 703882_2024-04-25
# 703882_2024-04-24_0 loaded
# probe_insertions.json and annotation info do not match for 703882_2024-04-24 - using annotation info
# Camera lines are plugged into sync incorrectly - we'll accommodate for this, but if this is a recent session check the rig: {'behavior': 'beh', 'face': 'eye', 'eye': 'face'}
# 703882_2024-04-23_0 loaded
# probe_insertions.json and annotation info do not match for 703882_2024-04-23 - using annotation info
# Camera lines are plugged into sync incorrectly - we'll accommodate for this, but if this is a recent session check the rig: {'behavior': 'beh', 'face': 'eye', 'eye': 'face'}
# 703882_2024-04-22_0 loaded
# probe_insertions.json and annotation info do not match for 703882_2024-04-22 - using annotation info
# Camera lines are plugged into sync incorrectly - we'll accommodate for this, but if this is a recent session check the rig: {'behavior': 'beh', 'face': 'eye', 'eye': 'face'}
# 706401_2024-04-22_0 loaded
# 699847_2024-04-18_0 loaded
# 703880_2024-04-18_0 loaded
# probe_insertions.json and annotation info do not match for 703880_2024-04-18 - using annotation info
# Camera lines are plugged into sync incorrectly - we'll accommodate for this, but if this is a recent session check the rig: {'behavior': 'beh', 'face': 'eye', 'eye': 'face'}
# 703880_2024-04-17_0 loaded
# probe_insertions.json and annotation info do not match for 703880_2024-04-17 - using annotation info
# Camera lines are plugged into sync incorrectly - we'll accommodate for this, but if this is a recent session check the rig: {'behavior': 'beh', 'face': 'eye', 'eye': 'face'}
# 699847_2024-04-17_0 loaded
# 699847_2024-04-16_0 loaded
# Session 699847_2024-04-15 has known issues: ['https://github.com/AllenInstitute/npc_sessions/issues/93']
# 699847_2024-04-15_0 loaded
# probe_insertions.json and annotation info do not match for 699847_2024-04-15 - using annotation info
# 703880_2024-04-15_0 loaded
# probe_insertions.json and annotation info do not match for 703880_2024-04-15 - using annotation info
# Camera lines are plugged into sync incorrectly - we'll accommodate for this, but if this is a recent session check the rig: {'behavior': 'beh', 'face': 'eye', 'eye': 'face'}
# 703333_2024-04-11_0 loaded
# Camera lines are plugged into sync incorrectly - we'll accommodate for this, but if this is a recent session check the rig: {'behavior': 'beh', 'face': 'eye', 'eye': 'face'}
# 703333_2024-04-10_0 loaded
# Camera lines are plugged into sync incorrectly - we'll accommodate for this, but if this is a recent session check the rig: {'behavior': 'beh', 'face': 'eye', 'eye': 'face'}
# 703333_2024-04-09_0 loaded
# no cached trials table, using npc_sessions
# No lick time found within response window on sync for trial 174, despite being marked as a response trial.
# No lick time found within response window on sync for trial 185, despite being marked as a response trial.
# Camera lines are plugged into sync incorrectly - we'll accommodate for this, but if this is a recent session check the rig: {'behavior': 'beh', 'face': 'eye', 'eye': 'face'}
# finished 703333_2024-04-09 0
# finished 703333_2024-04-09
# 703333_2024-04-08_0 loaded
# Camera lines are plugged into sync incorrectly - we'll accommodate for this, but if this is a recent session check the rig: {'behavior': 'beh', 'face': 'eye', 'eye': 'face'}
# finished 703333_2024-04-08 0
# finished 703333_2024-04-08
# 702136_2024-03-07_0 loaded
# probe_insertions.json and annotation info do not match for 702136_2024-03-07 - using annotation info
# finished 702136_2024-03-07 0
# finished 702136_2024-03-07
# 702136_2024-03-06_0 loaded
# probe_insertions.json and annotation info do not match for 702136_2024-03-06 - using annotation info
# finished 702136_2024-03-06 0
# finished 702136_2024-03-06
# 702136_2024-03-05_0 loaded
# finished 702136_2024-03-05 0
# finished 702136_2024-03-05
# 702131_2024-02-26_0 loaded
# finished 702131_2024-02-26 0
# finished 702131_2024-02-26
# 676909_2023-12-14_0 loaded
# probe_insertions.json and annotation info do not match for 676909_2023-12-14 - using annotation info
# finished 676909_2023-12-14 0
# finished 676909_2023-12-14
# 676909_2023-12-13_0 loaded
# probe_insertions.json and annotation info do not match for 676909_2023-12-13 - using annotation info
# finished 676909_2023-12-13 0
# finished 676909_2023-12-13
# 676909_2023-12-12_0 loaded
# finished 676909_2023-12-12 0
# finished 676909_2023-12-12
# 676909_2023-12-11_0 loaded
# finished 676909_2023-12-11 0
# finished 676909_2023-12-11
# 686176_2023-12-07_0 loaded
# finished 686176_2023-12-07 0
# finished 686176_2023-12-07
# Session 686176_2023-12-06 has known issues: ['https://github.com/AllenInstitute/npc_lims/issues/5']
# 686176_2023-12-06_0 loaded
# no cached trials table, using npc_sessions
# finished 686176_2023-12-06 0
# finished 686176_2023-12-06
# 686176_2023-12-05_0 loaded
# finished 686176_2023-12-05 0
# finished 686176_2023-12-05
# 686176_2023-12-04_0 loaded
# finished 686176_2023-12-04 0
# finished 686176_2023-12-04
# 690706_2023-11-30_0 loaded
# probe_insertions.json and annotation info do not match for 690706_2023-11-30 - using annotation info
# finished 690706_2023-11-30 0
# finished 690706_2023-11-30
# 690706_2023-11-29_0 loaded
# probe_insertions.json and annotation info do not match for 690706_2023-11-29 - using annotation info
# finished 690706_2023-11-29 0
# finished 690706_2023-11-29
# 690706_2023-11-28_0 loaded
# finished 690706_2023-11-28 0
# finished 690706_2023-11-28
# 690706_2023-11-27_0 loaded
# finished 690706_2023-11-27 0
# finished 690706_2023-11-27
# 664851_2023-11-16_0 loaded
# finished 664851_2023-11-16 0
# finished 664851_2023-11-16
# 664851_2023-11-15_0 loaded
# finished 664851_2023-11-15 0
# finished 664851_2023-11-15
# 664851_2023-11-14_0 loaded
# finished 664851_2023-11-14 0
# finished 664851_2023-11-14
# 664851_2023-11-13_0 loaded
# finished 664851_2023-11-13 0
# finished 664851_2023-11-13
# 686740_2023-10-26_0 loaded
# finished 686740_2023-10-26 0
# finished 686740_2023-10-26
# 686740_2023-10-25_0 loaded
# finished 686740_2023-10-25 0
# finished 686740_2023-10-25
# 686740_2023-10-24_0 loaded
# no cached trials table, using npc_sessions
# finished 686740_2023-10-24 0
# finished 686740_2023-10-24
# 686740_2023-10-23_0 loaded
# probe_insertions.json and annotation info do not match for 686740_2023-10-23 - using annotation info
# no cached trials table, using npc_sessions
# finished 686740_2023-10-23 0
# finished 686740_2023-10-23
# Session 681532_2023-10-19 has known issues: ['https://github.com/AllenInstitute/npc_lims/issues/5']
# 681532_2023-10-19_0 loaded
# no cached trials table, using npc_sessions
# No lick time found within response window on sync for trial 408, despite being marked as a response trial.
# finished 681532_2023-10-19 0
# finished 681532_2023-10-19
# 681532_2023-10-18_0 loaded
# finished 681532_2023-10-18 0
# finished 681532_2023-10-18
# 681532_2023-10-17_0 loaded
# finished 681532_2023-10-17 0
# finished 681532_2023-10-17
# 681532_2023-10-16_0 loaded
# finished 681532_2023-10-16 0
# finished 681532_2023-10-16
# 674562_2023-10-05_0 loaded
# finished 674562_2023-10-05 0
# finished 674562_2023-10-05
# 674562_2023-10-04_0 loaded
# finished 674562_2023-10-04 0
# finished 674562_2023-10-04
# 674562_2023-10-03_0 loaded
# finished 674562_2023-10-03 0
# finished 674562_2023-10-03
# 674562_2023-10-02_0 loaded
# finished 674562_2023-10-02 0
# finished 674562_2023-10-02
# 667252_2023-09-28_0 loaded
# finished 667252_2023-09-28 0
# finished 667252_2023-09-28
# Session 667252_2023-09-27 has known issues: ['https://github.com/AllenInstitute/npc_sessions/issues/55']
# 667252_2023-09-27_0 loaded
# no cached trials table, using npc_sessions
# Stim block_idx=4 has len(diode_flips)=213578 diode flips, len(vsyncs)=217297 vsyncs:too great a difference to correct. Returning display times based on vsync + constant lag.
# No lick time found within response window on sync for trial 135, despite being marked as a response trial.
# finished 667252_2023-09-27 0
# finished 667252_2023-09-27
# 667252_2023-09-26_0 loaded
# finished 667252_2023-09-26 0
# finished 667252_2023-09-26
# 667252_2023-09-25_0 loaded
# no cached trials table, using npc_sessions
# 668755_2023-08-31_0 loaded
# finished 668755_2023-08-31 0
# finished 668755_2023-08-31
# 668755_2023-08-30_0 loaded
# no cached trials table, using npc_sessions
# C:\Users\shailaja.akella\Anaconda3\envs\npc_sessions2\lib\site-packages\numcodecs\abc.py:107: UserWarning: Multi-threading is supported for wavpack version>=5.6.4, but current version is 5.5.0. Parallel decoding will not be available.
#   return cls(**config)
# aligning sound waveforms: 100%|████████████| 513/513 [01:10<00:00,  7.31trial/s]
# finished 668755_2023-08-30 0
# finished 668755_2023-08-30
# 668755_2023-08-29_0 loaded
# no cached trials table, using npc_sessions
# C:\Users\shailaja.akella\Anaconda3\envs\npc_sessions2\lib\site-packages\numcodecs\abc.py:107: UserWarning: Multi-threading is supported for wavpack version>=5.6.4, but current version is 5.5.0. Parallel decoding will not be available.
#   return cls(**config)
# aligning sound waveforms: 100%|████████████| 520/520 [01:10<00:00,  7.41trial/s]
# finished 668755_2023-08-29 0
# finished 668755_2023-08-29
# 668755_2023-08-28_0 loaded
# probe_insertions.json and annotation info do not match for 668755_2023-08-28 - using annotation info
# finished 668755_2023-08-28 0
# finished 668755_2023-08-28
# 662892_2023-08-24_0 loaded
# probe_insertions.json and annotation info do not match for 662892_2023-08-24 - using annotation info
# finished 662892_2023-08-24 0
# finished 662892_2023-08-24
# 662892_2023-08-23_0 loaded
# probe_insertions.json and annotation info do not match for 662892_2023-08-23 - using annotation info
# finished 662892_2023-08-23 0
# finished 662892_2023-08-23
# 662892_2023-08-22_0 loaded
# probe_insertions.json and annotation info do not match for 662892_2023-08-22 - using annotation info
# finished 662892_2023-08-22 0
# finished 662892_2023-08-22
# 662892_2023-08-21_0 loaded
# probe_insertions.json and annotation info do not match for 662892_2023-08-21 - using annotation info
# finished 662892_2023-08-21 0
# finished 662892_2023-08-21
# 666986_2023-08-17_0 loaded
# finished 666986_2023-08-17 0
# finished 666986_2023-08-17
# 666986_2023-08-16_0 loaded
# finished 666986_2023-08-16 0
# finished 666986_2023-08-16
# 666986_2023-08-15_0 loaded
# no cached trials table, using npc_sessions
# C:\Users\shailaja.akella\Anaconda3\envs\npc_sessions2\lib\site-packages\numcodecs\abc.py:107: UserWarning: Multi-threading is supported for wavpack version>=5.6.4, but current version is 5.5.0. Parallel decoding will not be available.
#   return cls(**config)
# aligning sound waveforms: 100%|████████████| 542/542 [00:57<00:00,  9.48trial/s]
# C:\Users\shailaja.akella\Dropbox (Personal)\DR\dynamic_routing_analysis_ethan\src\dynamic_routing_analysis\data_utils.py:146: RuntimeWarning: Mean of empty slice
#   mean_trial_behav_SVD[rr] = np.nanmean(behav_SVD_by_trial[rr],axis=0)
# 666986_2023-08-14_0 loaded
# no cached trials table, using npc_sessions
# Added two missed diode flips at start already, the max we can explain by pre-stim background & first diode square being similar luminance. This is a different problem: sync self.start_time=datetime.datetime(2023, 8, 14, 11, 38, 55, 122625)
# Returning display times based on vsync + constant lag for block_idx=3.
# C:\Users\shailaja.akella\Anaconda3\envs\npc_sessions2\lib\site-packages\numcodecs\abc.py:107: UserWarning: Multi-threading is supported for wavpack version>=5.6.4, but current version is 5.5.0. Parallel decoding will not be available.
#   return cls(**config)
# aligning sound waveforms: 100%|████████████| 519/519 [01:07<00:00,  7.72trial/s]
# finished 666986_2023-08-14 0
# finished 666986_2023-08-14
# 660023_2023-08-09_0 loaded
# no cached trials table, using npc_sessions
# C:\Users\shailaja.akella\Anaconda3\envs\npc_sessions2\lib\site-packages\numcodecs\abc.py:107: UserWarning: Multi-threading is supported for wavpack version>=5.6.4, but current version is 5.5.0. Parallel decoding will not be available.
#   return cls(**config)
# aligning sound waveforms: 100%|████████████| 501/501 [01:07<00:00,  7.45trial/s]
# No lick time found within response window on sync for trial 478, despite being marked as a response trial.
# C:\Users\shailaja.akella\Dropbox (Personal)\DR\dynamic_routing_analysis_ethan\src\dynamic_routing_analysis\data_utils.py:146: RuntimeWarning: Mean of empty slice
#   mean_trial_behav_SVD[rr] = np.nanmean(behav_SVD_by_trial[rr],axis=0)
# Session 670248_2023-08-03 has known issues: ['https://github.com/AllenInstitute/npc_sessions/issues/66']
# 670248_2023-08-03_0 loaded
# no cached trials table, using npc_sessions
# C:\Users\shailaja.akella\Anaconda3\envs\npc_sessions2\lib\site-packages\numcodecs\abc.py:107: UserWarning: Multi-threading is supported for wavpack version>=5.6.4, but current version is 5.5.0. Parallel decoding will not be available.
#   return cls(**config)
# trialSoundArray empty; regenerating sound arrays
# aligning sound waveforms:  91%|██████████▊ | 564/623 [01:30<00:09,  6.40trial/s]Requested range 143043820 to 143058835 on nidaq_channel=1 is out of bounds: nidaq_data.shape=(142823472, 8)
# No sound recording for trial 568 aud stim (presentation.trigger_time_on_sync=4783.46535 s) - setting latency=np.nan
# No sound recording for trial 569 aud stim (presentation.trigger_time_on_sync=4788.06909 s) - setting latency=np.nan
# No sound recording for trial 571 aud stim (presentation.trigger_time_on_sync=4799.76222 s) - setting latency=np.nan
# No sound recording for trial 572 aud stim (presentation.trigger_time_on_sync=4804.39952 s) - setting latency=np.nan
# No sound recording for trial 574 aud stim (presentation.trigger_time_on_sync=4814.95832 s) - setting latency=np.nan
# No sound recording for trial 578 aud stim (presentation.trigger_time_on_sync=4834.2913 s) - setting latency=np.nan
# No sound recording for trial 579 aud stim (presentation.trigger_time_on_sync=4839.49554 s) - setting latency=np.nan
# No sound recording for trial 582 aud stim (presentation.trigger_time_on_sync=4853.87439 s) - setting latency=np.nan
# No sound recording for trial 583 aud stim (presentation.trigger_time_on_sync=4858.94526 s) - setting latency=np.nan
# No sound recording for trial 584 aud stim (presentation.trigger_time_on_sync=4874.17462 s) - setting latency=np.nan
# No sound recording for trial 585 aud stim (presentation.trigger_time_on_sync=4878.81184 s) - setting latency=np.nan
# No sound recording for trial 592 aud stim (presentation.trigger_time_on_sync=4915.30907 s) - setting latency=np.nan
# No sound recording for trial 593 aud stim (presentation.trigger_time_on_sync=4920.02981 s) - setting latency=np.nan
# No sound recording for trial 594 aud stim (presentation.trigger_time_on_sync=4924.86715 s) - setting latency=np.nan
# No sound recording for trial 596 aud stim (presentation.trigger_time_on_sync=4934.14157 s) - setting latency=np.nan
# No sound recording for trial 598 aud stim (presentation.trigger_time_on_sync=4944.56705 s) - setting latency=np.nan
# No sound recording for trial 600 aud stim (presentation.trigger_time_on_sync=4954.9424 s) - setting latency=np.nan
# No sound recording for trial 602 aud stim (presentation.trigger_time_on_sync=4964.41699 s) - setting latency=np.nan
# No sound recording for trial 608 aud stim (presentation.trigger_time_on_sync=4995.04262 s) - setting latency=np.nan
# No sound recording for trial 610 aud stim (presentation.trigger_time_on_sync=5005.58472 s) - setting latency=np.nan
# No sound recording for trial 611 aud stim (presentation.trigger_time_on_sync=5010.63898 s) - setting latency=np.nan
# No sound recording for trial 614 aud stim (presentation.trigger_time_on_sync=5024.51733 s) - setting latency=np.nan
# No sound recording for trial 615 aud stim (presentation.trigger_time_on_sync=5029.15454 s) - setting latency=np.nan
# No sound recording for trial 618 aud stim (presentation.trigger_time_on_sync=5044.58402 s) - setting latency=np.nan
# aligning sound waveforms: 100%|████████████| 623/623 [01:30<00:00,  6.85trial/s]
# finished 670248_2023-08-03 0
# finished 670248_2023-08-03
# 670248_2023-08-01_0 loaded
# finished 670248_2023-08-01 0
# finished 670248_2023-08-01
# 670180_2023-07-27_0 loaded
# probe_insertions.json and annotation info do not match for 670180_2023-07-27 - using annotation info
# finished 670180_2023-07-27 0
# finished 670180_2023-07-27
# 670180_2023-07-26_0 loaded
# probe_insertions.json and annotation info do not match for 670180_2023-07-26 - using annotation info
# no cached trials table, using npc_sessions
# C:\Users\shailaja.akella\Anaconda3\envs\npc_sessions2\lib\site-packages\numcodecs\abc.py:107: UserWarning: Multi-threading is supported for wavpack version>=5.6.4, but current version is 5.5.0. Parallel decoding will not be available.
#   return cls(**config)
# trialSoundArray empty; regenerating sound arrays
# aligning sound waveforms: 100%|████████████| 643/643 [01:41<00:00,  6.35trial/s]
# finished 670180_2023-07-26 0
# finished 670180_2023-07-26
# Session 670181_2023-07-20 has known issues: ['https://github.com/AllenInstitute/npc_lims/issues/5']
# 670181_2023-07-20_0 loaded
# probe_insertions.json and annotation info do not match for 670181_2023-07-20 - using annotation info
# no cached trials table, using npc_sessions
# C:\Users\shailaja.akella\Anaconda3\envs\npc_sessions2\lib\site-packages\numcodecs\abc.py:107: UserWarning: Multi-threading is supported for wavpack version>=5.6.4, but current version is 5.5.0. Parallel decoding will not be available.
#   return cls(**config)
# trialSoundArray empty; regenerating sound arrays
# aligning sound waveforms:   0%|                      | 0/706 [00:00<?, ?trial/s]Requested range 63969929 to 63984944 on nidaq_channel=1 is out of bounds: nidaq_data.shape=(53056480, 8)
# No sound recording for trial 7 aud stim (presentation.trigger_time_on_sync=2150.30732 s) - setting latency=np.nan
# No sound recording for trial 10 aud stim (presentation.trigger_time_on_sync=2167.08791 s) - setting latency=np.nan
# No sound recording for trial 12 aud stim (presentation.trigger_time_on_sync=2177.14636 s) - setting latency=np.nan
# No sound recording for trial 13 aud stim (presentation.trigger_time_on_sync=2181.78355 s) - setting latency=np.nan
# No sound recording for trial 14 aud stim (presentation.trigger_time_on_sync=2187.22148 s) - setting latency=np.nan
# No sound recording for trial 16 aud stim (presentation.trigger_time_on_sync=2196.87959 s) - setting latency=np.nan
# No sound recording for trial 19 aud stim (presentation.trigger_time_on_sync=2211.70869 s) - setting latency=np.nan
# No sound recording for trial 22 aud stim (presentation.trigger_time_on_sync=2226.95477 s) - setting latency=np.nan
# No sound recording for trial 23 aud stim (presentation.trigger_time_on_sync=2232.35927 s) - setting latency=np.nan
# No sound recording for trial 26 aud stim (presentation.trigger_time_on_sync=2246.80473 s) - setting latency=np.nan
# No sound recording for trial 29 aud stim (presentation.trigger_time_on_sync=2261.56707 s) - setting latency=np.nan
# No sound recording for trial 31 aud stim (presentation.trigger_time_on_sync=2271.45885 s) - setting latency=np.nan
# No sound recording for trial 32 aud stim (presentation.trigger_time_on_sync=2276.6297 s) - setting latency=np.nan
# No sound recording for trial 36 aud stim (presentation.trigger_time_on_sync=2295.49559 s) - setting latency=np.nan
# No sound recording for trial 38 aud stim (presentation.trigger_time_on_sync=2305.90423 s) - setting latency=np.nan
# No sound recording for trial 40 aud stim (presentation.trigger_time_on_sync=2316.86347 s) - setting latency=np.nan
# No sound recording for trial 43 aud stim (presentation.trigger_time_on_sync=2333.27722 s) - setting latency=np.nan
# No sound recording for trial 44 aud stim (presentation.trigger_time_on_sync=2337.88106 s) - setting latency=np.nan
# No sound recording for trial 48 aud stim (presentation.trigger_time_on_sync=2356.91374 s) - setting latency=np.nan
# No sound recording for trial 50 aud stim (presentation.trigger_time_on_sync=2366.98878 s) - setting latency=np.nan
# No sound recording for trial 51 aud stim (presentation.trigger_time_on_sync=2372.47676 s) - setting latency=np.nan
# No sound recording for trial 52 aud stim (presentation.trigger_time_on_sync=2377.03063 s) - setting latency=np.nan
# No sound recording for trial 54 aud stim (presentation.trigger_time_on_sync=2386.47177 s) - setting latency=np.nan
# No sound recording for trial 55 aud stim (presentation.trigger_time_on_sync=2391.82629 s) - setting latency=np.nan
# No sound recording for trial 56 aud stim (presentation.trigger_time_on_sync=2396.69704 s) - setting latency=np.nan
# No sound recording for trial 60 aud stim (presentation.trigger_time_on_sync=2416.21336 s) - setting latency=np.nan
# No sound recording for trial 65 aud stim (presentation.trigger_time_on_sync=2441.55131 s) - setting latency=np.nan
# No sound recording for trial 67 aud stim (presentation.trigger_time_on_sync=2450.89245 s) - setting latency=np.nan
# No sound recording for trial 68 aud stim (presentation.trigger_time_on_sync=2455.93002 s) - setting latency=np.nan
# No sound recording for trial 75 aud stim (presentation.trigger_time_on_sync=2493.09449 s) - setting latency=np.nan
# No sound recording for trial 77 aud stim (presentation.trigger_time_on_sync=2504.05366 s) - setting latency=np.nan
# No sound recording for trial 79 aud stim (presentation.trigger_time_on_sync=2513.46153 s) - setting latency=np.nan
# No sound recording for trial 80 aud stim (presentation.trigger_time_on_sync=2518.36564 s) - setting latency=np.nan
# No sound recording for trial 82 aud stim (presentation.trigger_time_on_sync=2528.17389 s) - setting latency=np.nan
# No sound recording for trial 85 aud stim (presentation.trigger_time_on_sync=2542.81943 s) - setting latency=np.nan
# No sound recording for trial 86 aud stim (presentation.trigger_time_on_sync=2548.09055 s) - setting latency=np.nan
# No sound recording for trial 87 aud stim (presentation.trigger_time_on_sync=2552.69442 s) - setting latency=np.nan
# No sound recording for trial 89 aud stim (presentation.trigger_time_on_sync=2564.2374 s) - setting latency=np.nan
# No sound recording for trial 91 aud stim (presentation.trigger_time_on_sync=2575.0799 s) - setting latency=np.nan
# No sound recording for trial 97 aud stim (presentation.trigger_time_on_sync=2607.94069 s) - setting latency=np.nan
# No sound recording for trial 101 aud stim (presentation.trigger_time_on_sync=2629.47545 s) - setting latency=np.nan
# No sound recording for trial 105 aud stim (presentation.trigger_time_on_sync=2650.84329 s) - setting latency=np.nan
# No sound recording for trial 106 aud stim (presentation.trigger_time_on_sync=2655.46383 s) - setting latency=np.nan
# No sound recording for trial 107 aud stim (presentation.trigger_time_on_sync=2660.55148 s) - setting latency=np.nan
# No sound recording for trial 109 aud stim (presentation.trigger_time_on_sync=2670.30962 s) - setting latency=np.nan
# No sound recording for trial 110 aud stim (presentation.trigger_time_on_sync=2675.36389 s) - setting latency=np.nan
# No sound recording for trial 112 aud stim (presentation.trigger_time_on_sync=2686.42312 s) - setting latency=np.nan
# No sound recording for trial 116 aud stim (presentation.trigger_time_on_sync=2705.70599 s) - setting latency=np.nan
# No sound recording for trial 117 aud stim (presentation.trigger_time_on_sync=2710.94365 s) - setting latency=np.nan
# No sound recording for trial 119 aud stim (presentation.trigger_time_on_sync=2721.0522 s) - setting latency=np.nan
# No sound recording for trial 122 aud stim (presentation.trigger_time_on_sync=2735.61434 s) - setting latency=np.nan
# No sound recording for trial 126 aud stim (presentation.trigger_time_on_sync=2754.5969 s) - setting latency=np.nan
# No sound recording for trial 127 aud stim (presentation.trigger_time_on_sync=2759.18414 s) - setting latency=np.nan
# aligning sound waveforms:  18%|█▊        | 128/706 [00:00<00:00, 1267.03trial/s]No sound recording for trial 134 aud stim (presentation.trigger_time_on_sync=2796.78228 s) - setting latency=np.nan
# No sound recording for trial 135 aud stim (presentation.trigger_time_on_sync=2801.33611 s) - setting latency=np.nan
# No sound recording for trial 136 aud stim (presentation.trigger_time_on_sync=2805.92332 s) - setting latency=np.nan
# No sound recording for trial 137 aud stim (presentation.trigger_time_on_sync=2810.91079 s) - setting latency=np.nan
# No sound recording for trial 139 aud stim (presentation.trigger_time_on_sync=2822.10354 s) - setting latency=np.nan
# No sound recording for trial 143 aud stim (presentation.trigger_time_on_sync=2842.33717 s) - setting latency=np.nan
# No sound recording for trial 147 aud stim (presentation.trigger_time_on_sync=2861.88691 s) - setting latency=np.nan
# No sound recording for trial 148 aud stim (presentation.trigger_time_on_sync=2866.75759 s) - setting latency=np.nan
# No sound recording for trial 149 aud stim (presentation.trigger_time_on_sync=2873.27972 s) - setting latency=np.nan
# No sound recording for trial 150 aud stim (presentation.trigger_time_on_sync=2878.58423 s) - setting latency=np.nan
# No sound recording for trial 151 aud stim (presentation.trigger_time_on_sync=2883.15468 s) - setting latency=np.nan
# No sound recording for trial 153 aud stim (presentation.trigger_time_on_sync=2894.94787 s) - setting latency=np.nan
# No sound recording for trial 154 aud stim (presentation.trigger_time_on_sync=2899.71862 s) - setting latency=np.nan
# No sound recording for trial 157 aud stim (presentation.trigger_time_on_sync=2914.38096 s) - setting latency=np.nan
# No sound recording for trial 159 aud stim (presentation.trigger_time_on_sync=2924.97318 s) - setting latency=np.nan
# No sound recording for trial 163 aud stim (presentation.trigger_time_on_sync=2945.80729 s) - setting latency=np.nan
# No sound recording for trial 164 aud stim (presentation.trigger_time_on_sync=2950.46114 s) - setting latency=np.nan
# No sound recording for trial 171 aud stim (presentation.trigger_time_on_sync=2982.98831 s) - setting latency=np.nan
# No sound recording for trial 175 aud stim (presentation.trigger_time_on_sync=3003.00511 s) - setting latency=np.nan
# No sound recording for trial 176 aud stim (presentation.trigger_time_on_sync=3008.94347 s) - setting latency=np.nan
# No sound recording for trial 181 aud stim (presentation.trigger_time_on_sync=3033.14704 s) - setting latency=np.nan
# No sound recording for trial 182 aud stim (presentation.trigger_time_on_sync=3037.7342 s) - setting latency=np.nan
# No sound recording for trial 183 aud stim (presentation.trigger_time_on_sync=3042.30476 s) - setting latency=np.nan
# No sound recording for trial 184 aud stim (presentation.trigger_time_on_sync=3047.80939 s) - setting latency=np.nan
# No sound recording for trial 185 aud stim (presentation.trigger_time_on_sync=3053.23056 s) - setting latency=np.nan
# No sound recording for trial 187 aud stim (presentation.trigger_time_on_sync=3063.22225 s) - setting latency=np.nan
# No sound recording for trial 189 aud stim (presentation.trigger_time_on_sync=3073.48087 s) - setting latency=np.nan
# No sound recording for trial 192 aud stim (presentation.trigger_time_on_sync=3087.55943 s) - setting latency=np.nan
# No sound recording for trial 194 aud stim (presentation.trigger_time_on_sync=3097.50096 s) - setting latency=np.nan
# No sound recording for trial 197 aud stim (presentation.trigger_time_on_sync=3113.8981 s) - setting latency=np.nan
# No sound recording for trial 202 aud stim (presentation.trigger_time_on_sync=3140.35364 s) - setting latency=np.nan
# No sound recording for trial 203 aud stim (presentation.trigger_time_on_sync=3146.79225 s) - setting latency=np.nan
# No sound recording for trial 204 aud stim (presentation.trigger_time_on_sync=3155.69984 s) - setting latency=np.nan
# No sound recording for trial 205 aud stim (presentation.trigger_time_on_sync=3160.58729 s) - setting latency=np.nan
# No sound recording for trial 209 aud stim (presentation.trigger_time_on_sync=3180.60402 s) - setting latency=np.nan
# No sound recording for trial 211 aud stim (presentation.trigger_time_on_sync=3190.29552 s) - setting latency=np.nan
# No sound recording for trial 212 aud stim (presentation.trigger_time_on_sync=3194.89932 s) - setting latency=np.nan
# No sound recording for trial 213 aud stim (presentation.trigger_time_on_sync=3199.6366 s) - setting latency=np.nan
# No sound recording for trial 217 aud stim (presentation.trigger_time_on_sync=3218.50249 s) - setting latency=np.nan
# No sound recording for trial 218 aud stim (presentation.trigger_time_on_sync=3224.60746 s) - setting latency=np.nan
# No sound recording for trial 220 aud stim (presentation.trigger_time_on_sync=3235.16637 s) - setting latency=np.nan
# No sound recording for trial 221 aud stim (presentation.trigger_time_on_sync=3241.27147 s) - setting latency=np.nan
# No sound recording for trial 222 aud stim (presentation.trigger_time_on_sync=3246.20888 s) - setting latency=np.nan
# No sound recording for trial 223 aud stim (presentation.trigger_time_on_sync=3250.84618 s) - setting latency=np.nan
# No sound recording for trial 224 aud stim (presentation.trigger_time_on_sync=3255.48336 s) - setting latency=np.nan
# No sound recording for trial 227 aud stim (presentation.trigger_time_on_sync=3271.27995 s) - setting latency=np.nan
# No sound recording for trial 229 aud stim (presentation.trigger_time_on_sync=3281.33835 s) - setting latency=np.nan
# No sound recording for trial 237 aud stim (presentation.trigger_time_on_sync=3319.40355 s) - setting latency=np.nan
# No sound recording for trial 238 aud stim (presentation.trigger_time_on_sync=3324.55798 s) - setting latency=np.nan
# No sound recording for trial 241 aud stim (presentation.trigger_time_on_sync=3340.33784 s) - setting latency=np.nan
# No sound recording for trial 247 aud stim (presentation.trigger_time_on_sync=3371.31382 s) - setting latency=np.nan
# No sound recording for trial 248 aud stim (presentation.trigger_time_on_sync=3375.86758 s) - setting latency=np.nan
# No sound recording for trial 251 aud stim (presentation.trigger_time_on_sync=3390.64663 s) - setting latency=np.nan
# No sound recording for trial 252 aud stim (presentation.trigger_time_on_sync=3395.46733 s) - setting latency=np.nan
# No sound recording for trial 254 aud stim (presentation.trigger_time_on_sync=3406.66002 s) - setting latency=np.nan
# aligning sound waveforms:  36%|███▌      | 255/706 [00:00<00:00, 1095.34trial/s]No sound recording for trial 256 aud stim (presentation.trigger_time_on_sync=3417.38573 s) - setting latency=np.nan
# No sound recording for trial 257 aud stim (presentation.trigger_time_on_sync=3422.25647 s) - setting latency=np.nan
# No sound recording for trial 260 aud stim (presentation.trigger_time_on_sync=3436.98544 s) - setting latency=np.nan
# No sound recording for trial 261 aud stim (presentation.trigger_time_on_sync=3441.68941 s) - setting latency=np.nan
# No sound recording for trial 262 aud stim (presentation.trigger_time_on_sync=3446.32662 s) - setting latency=np.nan
# No sound recording for trial 263 aud stim (presentation.trigger_time_on_sync=3452.3317 s) - setting latency=np.nan
# No sound recording for trial 264 aud stim (presentation.trigger_time_on_sync=3457.60273 s) - setting latency=np.nan
# No sound recording for trial 267 aud stim (presentation.trigger_time_on_sync=3473.28259 s) - setting latency=np.nan
# No sound recording for trial 272 aud stim (presentation.trigger_time_on_sync=3498.65378 s) - setting latency=np.nan
# No sound recording for trial 273 aud stim (presentation.trigger_time_on_sync=3503.37444 s) - setting latency=np.nan
# No sound recording for trial 274 aud stim (presentation.trigger_time_on_sync=3508.14517 s) - setting latency=np.nan
# No sound recording for trial 280 aud stim (presentation.trigger_time_on_sync=3544.77582 s) - setting latency=np.nan
# No sound recording for trial 282 aud stim (presentation.trigger_time_on_sync=3554.68408 s) - setting latency=np.nan
# No sound recording for trial 285 aud stim (presentation.trigger_time_on_sync=3569.11289 s) - setting latency=np.nan
# No sound recording for trial 287 aud stim (presentation.trigger_time_on_sync=3579.82181 s) - setting latency=np.nan
# No sound recording for trial 288 aud stim (presentation.trigger_time_on_sync=3585.20971 s) - setting latency=np.nan
# No sound recording for trial 291 aud stim (presentation.trigger_time_on_sync=3599.58841 s) - setting latency=np.nan
# No sound recording for trial 293 aud stim (presentation.trigger_time_on_sync=3609.14636 s) - setting latency=np.nan
# No sound recording for trial 294 aud stim (presentation.trigger_time_on_sync=3613.90042 s) - setting latency=np.nan
# No sound recording for trial 302 aud stim (presentation.trigger_time_on_sync=3655.21841 s) - setting latency=np.nan
# No sound recording for trial 304 aud stim (presentation.trigger_time_on_sync=3666.01078 s) - setting latency=np.nan
# No sound recording for trial 305 aud stim (presentation.trigger_time_on_sync=3671.01496 s) - setting latency=np.nan
# No sound recording for trial 307 aud stim (presentation.trigger_time_on_sync=3681.74056 s) - setting latency=np.nan
# No sound recording for trial 308 aud stim (presentation.trigger_time_on_sync=3686.39456 s) - setting latency=np.nan
# No sound recording for trial 311 aud stim (presentation.trigger_time_on_sync=3701.75759 s) - setting latency=np.nan
# No sound recording for trial 315 aud stim (presentation.trigger_time_on_sync=3721.00681 s) - setting latency=np.nan
# No sound recording for trial 316 aud stim (presentation.trigger_time_on_sync=3725.87756 s) - setting latency=np.nan
# No sound recording for trial 319 aud stim (presentation.trigger_time_on_sync=3739.95602 s) - setting latency=np.nan
# No sound recording for trial 320 aud stim (presentation.trigger_time_on_sync=3744.5766 s) - setting latency=np.nan
# No sound recording for trial 322 aud stim (presentation.trigger_time_on_sync=3756.23632 s) - setting latency=np.nan
# No sound recording for trial 324 aud stim (presentation.trigger_time_on_sync=3766.32815 s) - setting latency=np.nan
# No sound recording for trial 325 aud stim (presentation.trigger_time_on_sync=3771.14884 s) - setting latency=np.nan
# No sound recording for trial 327 aud stim (presentation.trigger_time_on_sync=3781.09047 s) - setting latency=np.nan
# No sound recording for trial 331 aud stim (presentation.trigger_time_on_sync=3803.49265 s) - setting latency=np.nan
# No sound recording for trial 333 aud stim (presentation.trigger_time_on_sync=3813.35082 s) - setting latency=np.nan
# No sound recording for trial 338 aud stim (presentation.trigger_time_on_sync=3838.83888 s) - setting latency=np.nan
# No sound recording for trial 340 aud stim (presentation.trigger_time_on_sync=3849.93163 s) - setting latency=np.nan
# No sound recording for trial 341 aud stim (presentation.trigger_time_on_sync=3854.90242 s) - setting latency=np.nan
# No sound recording for trial 342 aud stim (presentation.trigger_time_on_sync=3859.90658 s) - setting latency=np.nan
# No sound recording for trial 343 aud stim (presentation.trigger_time_on_sync=3864.82728 s) - setting latency=np.nan
# No sound recording for trial 347 aud stim (presentation.trigger_time_on_sync=3886.86244 s) - setting latency=np.nan
# No sound recording for trial 348 aud stim (presentation.trigger_time_on_sync=3892.08349 s) - setting latency=np.nan
# No sound recording for trial 351 aud stim (presentation.trigger_time_on_sync=3906.41219 s) - setting latency=np.nan
# No sound recording for trial 352 aud stim (presentation.trigger_time_on_sync=3911.64991 s) - setting latency=np.nan
# No sound recording for trial 353 aud stim (presentation.trigger_time_on_sync=3916.53734 s) - setting latency=np.nan
# No sound recording for trial 355 aud stim (presentation.trigger_time_on_sync=3926.17878 s) - setting latency=np.nan
# No sound recording for trial 364 aud stim (presentation.trigger_time_on_sync=3969.14814 s) - setting latency=np.nan
# aligning sound waveforms:  52%|█████▏    | 366/706 [00:00<00:00, 1078.76trial/s]No sound recording for trial 368 aud stim (presentation.trigger_time_on_sync=3990.83293 s) - setting latency=np.nan
# No sound recording for trial 372 aud stim (presentation.trigger_time_on_sync=4010.64953 s) - setting latency=np.nan
# No sound recording for trial 373 aud stim (presentation.trigger_time_on_sync=4016.03743 s) - setting latency=np.nan
# No sound recording for trial 375 aud stim (presentation.trigger_time_on_sync=4026.44621 s) - setting latency=np.nan
# No sound recording for trial 376 aud stim (presentation.trigger_time_on_sync=4031.10002 s) - setting latency=np.nan
# No sound recording for trial 377 aud stim (presentation.trigger_time_on_sync=4036.15428 s) - setting latency=np.nan
# No sound recording for trial 382 aud stim (presentation.trigger_time_on_sync=4061.99265 s) - setting latency=np.nan
# No sound recording for trial 383 aud stim (presentation.trigger_time_on_sync=4067.49718 s) - setting latency=np.nan
# No sound recording for trial 386 aud stim (presentation.trigger_time_on_sync=4081.9761 s) - setting latency=np.nan
# No sound recording for trial 387 aud stim (presentation.trigger_time_on_sync=4086.51321 s) - setting latency=np.nan
# No sound recording for trial 390 aud stim (presentation.trigger_time_on_sync=4100.55825 s) - setting latency=np.nan
# No sound recording for trial 391 aud stim (presentation.trigger_time_on_sync=4105.87934 s) - setting latency=np.nan
# No sound recording for trial 392 aud stim (presentation.trigger_time_on_sync=4110.54991 s) - setting latency=np.nan
# No sound recording for trial 394 aud stim (presentation.trigger_time_on_sync=4120.37481 s) - setting latency=np.nan
# No sound recording for trial 398 aud stim (presentation.trigger_time_on_sync=4141.64273 s) - setting latency=np.nan
# No sound recording for trial 400 aud stim (presentation.trigger_time_on_sync=4151.35077 s) - setting latency=np.nan
# No sound recording for trial 405 aud stim (presentation.trigger_time_on_sync=4176.37174 s) - setting latency=np.nan
# No sound recording for trial 407 aud stim (presentation.trigger_time_on_sync=4186.33004 s) - setting latency=np.nan
# No sound recording for trial 410 aud stim (presentation.trigger_time_on_sync=4200.67552 s) - setting latency=np.nan
# No sound recording for trial 412 aud stim (presentation.trigger_time_on_sync=4210.78396 s) - setting latency=np.nan
# No sound recording for trial 415 aud stim (presentation.trigger_time_on_sync=4226.16352 s) - setting latency=np.nan
# No sound recording for trial 416 aud stim (presentation.trigger_time_on_sync=4230.78398 s) - setting latency=np.nan
# No sound recording for trial 419 aud stim (presentation.trigger_time_on_sync=4244.52885 s) - setting latency=np.nan
# No sound recording for trial 422 aud stim (presentation.trigger_time_on_sync=4261.34302 s) - setting latency=np.nan
# No sound recording for trial 423 aud stim (presentation.trigger_time_on_sync=4266.29715 s) - setting latency=np.nan
# No sound recording for trial 425 aud stim (presentation.trigger_time_on_sync=4276.539 s) - setting latency=np.nan
# No sound recording for trial 427 aud stim (presentation.trigger_time_on_sync=4287.46493 s) - setting latency=np.nan
# No sound recording for trial 429 aud stim (presentation.trigger_time_on_sync=4297.87352 s) - setting latency=np.nan
# No sound recording for trial 432 aud stim (presentation.trigger_time_on_sync=4311.90215 s) - setting latency=np.nan
# No sound recording for trial 433 aud stim (presentation.trigger_time_on_sync=4316.75605 s) - setting latency=np.nan
# No sound recording for trial 434 aud stim (presentation.trigger_time_on_sync=4324.92953 s) - setting latency=np.nan
# No sound recording for trial 438 aud stim (presentation.trigger_time_on_sync=4346.71449 s) - setting latency=np.nan
# No sound recording for trial 442 aud stim (presentation.trigger_time_on_sync=4368.16584 s) - setting latency=np.nan
# No sound recording for trial 443 aud stim (presentation.trigger_time_on_sync=4372.76972 s) - setting latency=np.nan
# No sound recording for trial 444 aud stim (presentation.trigger_time_on_sync=4377.42356 s) - setting latency=np.nan
# No sound recording for trial 446 aud stim (presentation.trigger_time_on_sync=4387.53202 s) - setting latency=np.nan
# No sound recording for trial 447 aud stim (presentation.trigger_time_on_sync=4392.21928 s) - setting latency=np.nan
# No sound recording for trial 448 aud stim (presentation.trigger_time_on_sync=4397.05673 s) - setting latency=np.nan
# No sound recording for trial 451 aud stim (presentation.trigger_time_on_sync=4412.70312 s) - setting latency=np.nan
# No sound recording for trial 460 aud stim (presentation.trigger_time_on_sync=4458.87516 s) - setting latency=np.nan
# No sound recording for trial 461 aud stim (presentation.trigger_time_on_sync=4463.64582 s) - setting latency=np.nan
# No sound recording for trial 462 aud stim (presentation.trigger_time_on_sync=4468.34972 s) - setting latency=np.nan
# No sound recording for trial 464 aud stim (presentation.trigger_time_on_sync=4479.70937 s) - setting latency=np.nan
# No sound recording for trial 466 aud stim (presentation.trigger_time_on_sync=4489.30071 s) - setting latency=np.nan
# No sound recording for trial 467 aud stim (presentation.trigger_time_on_sync=4494.82198 s) - setting latency=np.nan
# No sound recording for trial 468 aud stim (presentation.trigger_time_on_sync=4499.47591 s) - setting latency=np.nan
# No sound recording for trial 471 aud stim (presentation.trigger_time_on_sync=4520.92713 s) - setting latency=np.nan
# No sound recording for trial 473 aud stim (presentation.trigger_time_on_sync=4530.51852 s) - setting latency=np.nan
# No sound recording for trial 474 aud stim (presentation.trigger_time_on_sync=4535.75623 s) - setting latency=np.nan
# No sound recording for trial 475 aud stim (presentation.trigger_time_on_sync=4540.72708 s) - setting latency=np.nan
# No sound recording for trial 476 aud stim (presentation.trigger_time_on_sync=4545.33093 s) - setting latency=np.nan
# No sound recording for trial 479 aud stim (presentation.trigger_time_on_sync=4560.49364 s) - setting latency=np.nan
# No sound recording for trial 480 aud stim (presentation.trigger_time_on_sync=4566.14842 s) - setting latency=np.nan
# aligning sound waveforms:  68%|██████▊   | 481/706 [00:00<00:00, 1105.01trial/s]No sound recording for trial 482 aud stim (presentation.trigger_time_on_sync=4576.70719 s) - setting latency=np.nan
# No sound recording for trial 488 aud stim (presentation.trigger_time_on_sync=4605.49808 s) - setting latency=np.nan
# No sound recording for trial 490 aud stim (presentation.trigger_time_on_sync=4614.80578 s) - setting latency=np.nan
# No sound recording for trial 492 aud stim (presentation.trigger_time_on_sync=4625.28133 s) - setting latency=np.nan
# No sound recording for trial 497 aud stim (presentation.trigger_time_on_sync=4649.65166 s) - setting latency=np.nan
# ...
#   warnings.warn(
# C:\Users\shailaja.akella\Anaconda3\envs\npc_sessions2\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\shailaja.akella\Anaconda3\envs\npc_sessions2\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\shailaja.akella\Anaconda3\envs\npc_sessions2\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\shailaja.akella\Anaconda3\envs\npc_sessions2\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\shailaja.akella\Anaconda3\envs\npc_sessions2\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\shailaja.akella\Anaconda3\envs\npc_sessions2\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\shailaja.akella\Anaconda3\envs\npc_sessions2\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\shailaja.akella\Anaconda3\envs\npc_sessions2\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\shailaja.akella\Anaconda3\envs\npc_sessions2\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\shailaja.akella\Anaconda3\envs\npc_sessions2\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\shailaja.akella\Anaconda3\envs\npc_sessions2\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\shailaja.akella\Anaconda3\envs\npc_sessions2\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\shailaja.akella\Anaconda3\envs\npc_sessions2\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\shailaja.akella\Anaconda3\envs\npc_sessions2\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\shailaja.akella\Anaconda3\envs\npc_sessions2\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\shailaja.akella\Anaconda3\envs\npc_sessions2\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\shailaja.akella\Anaconda3\envs\npc_sessions2\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\shailaja.akella\Anaconda3\envs\npc_sessions2\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\shailaja.akella\Anaconda3\envs\npc_sessions2\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\shailaja.akella\Anaconda3\envs\npc_sessions2\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\shailaja.akella\Anaconda3\envs\npc_sessions2\lib\site-packages\sklearn\svm\_base.py:1237: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# finished 646318_2023-01-18 0
# finished 646318_2023-01-18
# 646318_2023-01-17_0 loaded
# finished 646318_2023-01-17 0
# finished 646318_2023-01-17
# 644547_2022-12-06_0 loaded
# 644547_2022-12-05_0 loaded
# 636397_2022-09-27_0 loaded
# finished 636397_2022-09-27 0
# finished 636397_2022-09-27
# 636397_2022-09-26_0 loaded
# finished 636397_2022-09-26 0
# finished 636397_2022-09-26
# Session 628801_2022-09-20 has known issues: ['https://github.com/AllenInstitute/npc_sessions/issues/27', 'https://github.com/AllenInstitute/npc_lims/issues/5']
# 628801_2022-09-20_0 loaded
# no cached trials table, using npc_sessions
# C:\Users\shailaja.akella\Anaconda3\envs\npc_sessions2\lib\site-packages\numcodecs\abc.py:107: UserWarning: Multi-threading is supported for wavpack version>=5.6.4, but current version is 5.5.0. Parallel decoding will not be available.
#   return cls(**config)
# aligning sound waveforms:  71%|████████▌   | 474/665 [01:10<00:27,  6.84trial/s]Requested range 81558928 to 81573943 on nidaq_channel=1 is out of bounds: nidaq_data.shape=(80547504, 8)
# No sound recording for trial 482 aud stim (presentation.trigger_time_on_sync=2731.35285 s) - setting latency=np.nan
# No sound recording for trial 484 aud stim (presentation.trigger_time_on_sync=2741.1439 s) - setting latency=np.nan
# No sound recording for trial 485 aud stim (presentation.trigger_time_on_sync=2745.71436 s) - setting latency=np.nan
# No sound recording for trial 486 aud stim (presentation.trigger_time_on_sync=2750.46869 s) - setting latency=np.nan
# No sound recording for trial 487 aud stim (presentation.trigger_time_on_sync=2755.25553 s) - setting latency=np.nan
# No sound recording for trial 489 aud stim (presentation.trigger_time_on_sync=2767.71596 s) - setting latency=np.nan
# No sound recording for trial 490 aud stim (presentation.trigger_time_on_sync=2772.38649 s) - setting latency=np.nan
# No sound recording for trial 494 aud stim (presentation.trigger_time_on_sync=2793.90484 s) - setting latency=np.nan
# No sound recording for trial 496 aud stim (presentation.trigger_time_on_sync=2803.72915 s) - setting latency=np.nan
# No sound recording for trial 498 aud stim (presentation.trigger_time_on_sync=2813.93797 s) - setting latency=np.nan
# No sound recording for trial 500 aud stim (presentation.trigger_time_on_sync=2823.67916 s) - setting latency=np.nan
# No sound recording for trial 504 aud stim (presentation.trigger_time_on_sync=2846.83157 s) - setting latency=np.nan
# No sound recording for trial 506 aud stim (presentation.trigger_time_on_sync=2857.19022 s) - setting latency=np.nan
# No sound recording for trial 507 aud stim (presentation.trigger_time_on_sync=2863.61214 s) - setting latency=np.nan
# No sound recording for trial 509 aud stim (presentation.trigger_time_on_sync=2873.22016 s) - setting latency=np.nan
# No sound recording for trial 512 aud stim (presentation.trigger_time_on_sync=2888.23261 s) - setting latency=np.nan
# No sound recording for trial 513 aud stim (presentation.trigger_time_on_sync=2893.43694 s) - setting latency=np.nan
# No sound recording for trial 516 aud stim (presentation.trigger_time_on_sync=2911.16881 s) - setting latency=np.nan
# No sound recording for trial 519 aud stim (presentation.trigger_time_on_sync=2928.3159 s) - setting latency=np.nan
# No sound recording for trial 520 aud stim (presentation.trigger_time_on_sync=2933.23661 s) - setting latency=np.nan
# No sound recording for trial 523 aud stim (presentation.trigger_time_on_sync=2948.03223 s) - setting latency=np.nan
# No sound recording for trial 524 aud stim (presentation.trigger_time_on_sync=2952.56937 s) - setting latency=np.nan
# No sound recording for trial 525 aud stim (presentation.trigger_time_on_sync=2958.92474 s) - setting latency=np.nan
# No sound recording for trial 530 aud stim (presentation.trigger_time_on_sync=2990.08388 s) - setting latency=np.nan
# No sound recording for trial 532 aud stim (presentation.trigger_time_on_sync=3004.41244 s) - setting latency=np.nan
# No sound recording for trial 536 aud stim (presentation.trigger_time_on_sync=3029.91691 s) - setting latency=np.nan
# No sound recording for trial 537 aud stim (presentation.trigger_time_on_sync=3035.28806 s) - setting latency=np.nan
# No sound recording for trial 538 aud stim (presentation.trigger_time_on_sync=3040.20877 s) - setting latency=np.nan
# No sound recording for trial 540 aud stim (presentation.trigger_time_on_sync=3052.26882 s) - setting latency=np.nan
# No sound recording for trial 541 aud stim (presentation.trigger_time_on_sync=3057.74002 s) - setting latency=np.nan
# No sound recording for trial 543 aud stim (presentation.trigger_time_on_sync=3070.71744 s) - setting latency=np.nan
# No sound recording for trial 545 aud stim (presentation.trigger_time_on_sync=3080.64233 s) - setting latency=np.nan
# No sound recording for trial 552 aud stim (presentation.trigger_time_on_sync=3117.20594 s) - setting latency=np.nan
# No sound recording for trial 553 aud stim (presentation.trigger_time_on_sync=3122.04337 s) - setting latency=np.nan
# No sound recording for trial 557 aud stim (presentation.trigger_time_on_sync=3141.32593 s) - setting latency=np.nan
# No sound recording for trial 558 aud stim (presentation.trigger_time_on_sync=3145.91307 s) - setting latency=np.nan
# No sound recording for trial 559 aud stim (presentation.trigger_time_on_sync=3151.41762 s) - setting latency=np.nan
# No sound recording for trial 561 aud stim (presentation.trigger_time_on_sync=3167.1306 s) - setting latency=np.nan
# No sound recording for trial 562 aud stim (presentation.trigger_time_on_sync=3172.01814 s) - setting latency=np.nan
# No sound recording for trial 563 aud stim (presentation.trigger_time_on_sync=3176.58849 s) - setting latency=np.nan
# No sound recording for trial 565 aud stim (presentation.trigger_time_on_sync=3190.38324 s) - setting latency=np.nan
# No sound recording for trial 567 aud stim (presentation.trigger_time_on_sync=3199.70763 s) - setting latency=np.nan
# No sound recording for trial 570 aud stim (presentation.trigger_time_on_sync=3215.55418 s) - setting latency=np.nan
# No sound recording for trial 578 aud stim (presentation.trigger_time_on_sync=3264.7284 s) - setting latency=np.nan
# No sound recording for trial 579 aud stim (presentation.trigger_time_on_sync=3269.39871 s) - setting latency=np.nan
# No sound recording for trial 580 aud stim (presentation.trigger_time_on_sync=3274.3364 s) - setting latency=np.nan
# No sound recording for trial 581 aud stim (presentation.trigger_time_on_sync=3279.50707 s) - setting latency=np.nan
# No sound recording for trial 582 aud stim (presentation.trigger_time_on_sync=3285.27855 s) - setting latency=np.nan
# No sound recording for trial 587 aud stim (presentation.trigger_time_on_sync=3309.36526 s) - setting latency=np.nan
# No sound recording for trial 588 aud stim (presentation.trigger_time_on_sync=3314.2194 s) - setting latency=np.nan
# No sound recording for trial 589 aud stim (presentation.trigger_time_on_sync=3318.93987 s) - setting latency=np.nan
# No sound recording for trial 591 aud stim (presentation.trigger_time_on_sync=3330.21586 s) - setting latency=np.nan
# No sound recording for trial 593 aud stim (presentation.trigger_time_on_sync=3340.55825 s) - setting latency=np.nan
# No sound recording for trial 594 aud stim (presentation.trigger_time_on_sync=3346.02982 s) - setting latency=np.nan
# No sound recording for trial 598 aud stim (presentation.trigger_time_on_sync=3365.97883 s) - setting latency=np.nan
# No sound recording for trial 601 aud stim (presentation.trigger_time_on_sync=3384.71108 s) - setting latency=np.nan
# No sound recording for trial 603 aud stim (presentation.trigger_time_on_sync=3394.53632 s) - setting latency=np.nan
# No sound recording for trial 604 aud stim (presentation.trigger_time_on_sync=3399.27346 s) - setting latency=np.nan
# No sound recording for trial 605 aud stim (presentation.trigger_time_on_sync=3405.56195 s) - setting latency=np.nan
# No sound recording for trial 608 aud stim (presentation.trigger_time_on_sync=3420.84104 s) - setting latency=np.nan
# No sound recording for trial 611 aud stim (presentation.trigger_time_on_sync=3438.23879 s) - setting latency=np.nan
# No sound recording for trial 612 aud stim (presentation.trigger_time_on_sync=3444.02698 s) - setting latency=np.nan
# No sound recording for trial 613 aud stim (presentation.trigger_time_on_sync=3449.44864 s) - setting latency=np.nan
# No sound recording for trial 615 aud stim (presentation.trigger_time_on_sync=3459.33969 s) - setting latency=np.nan
# No sound recording for trial 616 aud stim (presentation.trigger_time_on_sync=3464.6107 s) - setting latency=np.nan
# No sound recording for trial 618 aud stim (presentation.trigger_time_on_sync=3474.48561 s) - setting latency=np.nan
# No sound recording for trial 622 aud stim (presentation.trigger_time_on_sync=3495.1034 s) - setting latency=np.nan
# No sound recording for trial 624 aud stim (presentation.trigger_time_on_sync=3505.04423 s) - setting latency=np.nan
# No sound recording for trial 628 aud stim (presentation.trigger_time_on_sync=3524.86096 s) - setting latency=np.nan
# No sound recording for trial 631 aud stim (presentation.trigger_time_on_sync=3539.20594 s) - setting latency=np.nan
# No sound recording for trial 632 aud stim (presentation.trigger_time_on_sync=3544.59382 s) - setting latency=np.nan
# No sound recording for trial 640 aud stim (presentation.trigger_time_on_sync=3582.94239 s) - setting latency=np.nan
# No sound recording for trial 643 aud stim (presentation.trigger_time_on_sync=3599.37252 s) - setting latency=np.nan
# No sound recording for trial 645 aud stim (presentation.trigger_time_on_sync=3608.58012 s) - setting latency=np.nan
# No sound recording for trial 648 aud stim (presentation.trigger_time_on_sync=3624.32657 s) - setting latency=np.nan
# No sound recording for trial 649 aud stim (presentation.trigger_time_on_sync=3628.91372 s) - setting latency=np.nan
# No sound recording for trial 653 aud stim (presentation.trigger_time_on_sync=3656.48658 s) - setting latency=np.nan
# No sound recording for trial 655 aud stim (presentation.trigger_time_on_sync=3669.46572 s) - setting latency=np.nan
# No sound recording for trial 656 aud stim (presentation.trigger_time_on_sync=3675.23553 s) - setting latency=np.nan
# No sound recording for trial 657 aud stim (presentation.trigger_time_on_sync=3680.55667 s) - setting latency=np.nan
# No sound recording for trial 660 aud stim (presentation.trigger_time_on_sync=3695.75249 s) - setting latency=np.nan
# aligning sound waveforms:  99%|██████████▉| 661/665 [01:10<00:00, 253.65trial/s]No sound recording for trial 662 aud stim (presentation.trigger_time_on_sync=3706.26165 s) - setting latency=np.nan
# aligning sound waveforms: 100%|████████████| 665/665 [01:10<00:00,  9.46trial/s]
# No lick time found within response window on sync for trial 624, despite being marked as a response trial.
# 628801_2022-09-19_0 loaded
# C:\Users\shailaja.akella\Dropbox (Personal)\DR\dynamic_routing_analysis_ethan\src\dynamic_routing_analysis\data_utils.py:146: RuntimeWarning: Mean of empty slice
#   mean_trial_behav_SVD[rr] = np.nanmean(behav_SVD_by_trial[rr],axis=0)
# finished 628801_2022-09-19 0
# finished 628801_2022-09-19
# 626791_2022-08-17_0 loaded
# finished 626791_2022-08-17 0
# finished 626791_2022-08-17
# 626791_2022-08-16_0 loaded
# finished 626791_2022-08-16 0
# finished 626791_2022-08-16
# 626791_2022-08-15_0 loaded
# finished 626791_2022-08-15 0
# finished 626791_2022-08-15
# 620264_2022-08-02_0 loaded
# finished 620264_2022-08-02 0
# finished 620264_2022-08-02
# 620263_2022-07-27_0 loaded
# finished 620263_2022-07-27 0
# finished 620263_2022-07-27
# 620263_2022-07-26_0 loaded
# finished 620263_2022-07-26 0
# finished 620263_2022-07-26

# %%
except_list
# Out:
# {'712815_2024-05-20': "ValueError('could not broadcast input array from shape (0,500) into shape (12,500)')",
#  '703882_2024-04-24': "ValueError('could not broadcast input array from shape (0,500) into shape (12,500)')",
#  '703882_2024-04-23': "ValueError('could not broadcast input array from shape (0,500) into shape (12,500)')",
#  '703882_2024-04-22': "ValueError('could not broadcast input array from shape (0,500) into shape (12,500)')",
#  '706401_2024-04-22': "ValueError('could not broadcast input array from shape (0,500) into shape (12,500)')",
#  '699847_2024-04-18': "ValueError('could not broadcast input array from shape (0,500) into shape (12,500)')",
#  '703880_2024-04-18': "ValueError('could not broadcast input array from shape (0,500) into shape (12,500)')",
#  '703880_2024-04-17': "ValueError('could not broadcast input array from shape (0,500) into shape (12,500)')",
#  '699847_2024-04-17': "ValueError('could not broadcast input array from shape (0,500) into shape (12,500)')",
#  '699847_2024-04-16': "ValueError('could not broadcast input array from shape (0,500) into shape (12,500)')",
#  '699847_2024-04-15': "ValueError('could not broadcast input array from shape (0,500) into shape (12,500)')",
#  '703880_2024-04-15': "ValueError('could not broadcast input array from shape (0,500) into shape (12,500)')",
#  '703333_2024-04-11': "ValueError('could not broadcast input array from shape (0,500) into shape (12,500)')",
#  '703333_2024-04-10': "ValueError('could not broadcast input array from shape (0,500) into shape (12,500)')",
#  '667252_2023-09-25': "IndexError('index 0 is out of bounds for axis 0 with size 0')",
#  '666986_2023-08-15': "ValueError('Found array with 0 sample(s) (shape=(0, 500)) while a minimum of 1 is required by RobustScaler.')",
#  '660023_2023-08-09': "ValueError('This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0')",
#  '644547_2022-12-06': "FileNotFoundError('644547_2022-12-06 has no facemap results')",
#  '644547_2022-12-05': "FileNotFoundError('644547_2022-12-05 has no facemap results')",
#  '628801_2022-09-20': "FileNotFoundError('No motSVD file found for session 628801_2022-09-20 face camera, despite other paths existing. Check codeocean')"}
