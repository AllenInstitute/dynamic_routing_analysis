# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import npc_io

# %%
s3_path = "s3://aind-scratch-data/dynamic-routing/cache/nwb_components/v0.0.265/consolidated/units.parquet"
df = pd.read_parquet(s3_path)

# %%
from dynamic_routing_analysis import plot_utils

# %%
chart, _ = plot_utils.plot_brain_heatmap(regions=['VISp'],values=[0.5],sagittal_planes=3000,interactive=True);
chart
# Out:
# WARNING:dynamic_routing_analysis.plot_utils:Color encoding for regions with no values does not work correctly
# WARNING:dynamic_routing_analysis.plot_utils:Removing 289 regions as they are parents of other regions (remove_redundant_parents=True): ['root' 'grey' 'CH' 'CTX' 'CTXpl' 'Isocortex' 'FRP' 'MO' 'MOp' 'MOs' 'SS'
#  'SSp' 'SSp-n' 'SSp-bfd' 'VISrll' 'SSp-ll' 'SSp-m' 'SSp-ul' 'SSp-tr'
#  'SSp-un' 'SSs' 'GU' 'VISC' 'AUD' 'AUDd' 'VISlla' 'AUDp' 'AUDpo' 'AUDv'
#  'VIS' 'VISal' 'VISam' 'VISl' 'VISp' 'VISpl' 'VISpm' 'VISli' 'VISpor'
#  'ACA' 'ACAd' 'ACAv' 'PL' 'ILA' 'ORB' 'ORBl' 'ORBm' 'ORBvl' 'AI' 'AId'
#  'AIp' 'AIv' 'RSP' 'RSPagl' 'VISmma' 'VISmmp' 'VISm' 'RSPd' 'RSPv' 'PTLp'
#  'VISa' 'VISrl' 'TEa' 'PERI' 'ECT' 'OLF' 'MOB' 'AOB' 'AON' 'TT' 'TTd'
#  'TTv' 'DP' 'PIR' 'NLOT' 'COA' 'COAa' 'COAp' 'COApl' 'COApm' 'PAA' 'TR'
#  'HPF' 'HIP' 'CA' 'CA1' 'CA2' 'CA3' 'DG' 'DGcr' 'DGlb' 'DGmb' 'RHP' 'ENT'
#  'ENTl' 'ENTm' 'ENTmv' 'PAR' 'POST' 'PRE' 'SUB' 'SUBd' 'SUBv' 'ProS'
# ...
